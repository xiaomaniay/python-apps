# %%
import yfinance as yf
data = yf.download("MMM", start="2018-01-01", end="2019-12-31")
data.to_csv(r'/Users/xiaomanli/Desktop/3M.csv')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
import yfinance as yf
msft = yf.download("MSFT", start="2018-01-01", end="2019-12-31")
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
data.head()
# Out:
#                  Open       High        Low      Close  Adj Close  Volume
# Date
# 2018-01-02  41.533333  42.766666  41.013332  42.756668  42.005821   45300
# 2018-01-03  42.826668  43.830002  42.763332  43.830002  43.060307   49800
# 2018-01-04  44.213333  44.213333  43.090000  43.956665  43.184746   29100
# 2018-01-05  44.306667  44.630001  43.919998  44.286667  43.508953   42900
# 2018-01-08  44.563332  45.416668  44.293335  45.139999  44.347294   84300

# %%
import ta
msft = ta.utils.dropna(msft)

# Add all ta features
msft = ta.add_all_ta_features(
    msft, open="Open", high="High", low="Low", close="Close", volume="Volume")
# Out:
# /Users/xiaomanli/python-apps/trading/lib/python3.7/site-packages/ta/trend.py:543: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i]/self._trs[i])
# /Users/xiaomanli/python-apps/trading/lib/python3.7/site-packages/ta/trend.py:547: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i]/self._trs[i])

# %%
# Initialize Bollinger Bands Indicator
indicator_bb = ta.volatility.BollingerBands(close=msft["Close"], n=20, ndev=2)

# Add Bollinger Bands features
msft['bb_bbm'] = indicator_bb.bollinger_mavg()
msft['bb_bbh'] = indicator_bb.bollinger_hband()
msft['bb_bbl'] = indicator_bb.bollinger_lband()

# Add Bollinger Band high indicator
msft['bb_bbhi'] = indicator_bb.bollinger_hband_indicator()

# Add Bollinger Band low indicator
msft['bb_bbli'] = indicator_bb.bollinger_lband_indicator()

# Add width size Bollinger Bands
msft['bb_bbw'] = indicator_bb.bollinger_wband()

# %%
msft.head()
# Out:
#                  Open       High        Low      Close  Adj Close    Volume  \
# Date
# 2018-01-02  86.129997  86.309998  85.500000  85.949997  83.029594  22483800
# 2018-01-03  86.059998  86.510002  85.970001  86.349998  83.415993  26061400
# 2018-01-04  86.589996  87.660004  86.570000  87.110001  84.150192  21912000
# 2018-01-05  87.660004  88.410004  87.430000  88.190002  85.193497  23407100
# 2018-01-08  88.199997  88.580002  87.599998  88.279999  85.280426  22113000
#
#               volume_adi  volume_obv  volume_cmf  volume_fi  ...  \
# Date                                                         ...
# 2018-01-02  2.498106e+06    22483800    0.111107        NaN  ...
# 2018-01-03  1.311539e+07    48545200    0.270169        NaN  ...
# 2018-01-04  1.291432e+07    70457200    0.183293        NaN  ...
# 2018-01-05  2.581208e+07    93864300    0.274994        NaN  ...
# 2018-01-08  3.438642e+07   115977300    0.296493        NaN  ...
#
#             momentum_roc  others_dr  others_dlr  others_cr     bb_bbm  \
# Date
# 2018-01-02           NaN -25.683241         NaN   0.000000  85.949997
# 2018-01-03           NaN   0.465389    0.464309   0.465389  86.149998
# 2018-01-04           NaN   0.880141    0.876291   1.349626  86.469999
# 2018-01-05           NaN   1.239814    1.232191   2.606173  86.900000
# 2018-01-08           NaN   0.102048    0.101996   2.710881  87.175999
#
#                bb_bbh     bb_bbl  bb_bbhi  bb_bbli    bb_bbw
# Date
# 2018-01-02  85.949997  85.949997      0.0      0.0  0.000000
# 2018-01-03  86.549999  85.749996      0.0      0.0  0.800003
# 2018-01-04  87.432221  85.507776      0.0      0.0  1.924445
# 2018-01-05  88.606814  85.193186      0.0      0.0  3.413628
# 2018-01-08  89.059981  85.292018      0.0      0.0  3.767963
#
# [5 rows x 79 columns]

# %%
a = 3

# %%
data.to_csv(r'/Users/xiaomanli/Desktop/test.csv')

# %%
data = yf.download("MMM", start='2000-01-01', end='2019-04-29')
# Out:
# [*********************100%***********************]  1 of 1 downloaded

# %%
data.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  4860.000000  4860.000000  4860.000000  4860.000000  4860.000000
# mean    103.984286   104.810580   103.157206   104.015634    87.297049
# std      50.631300    50.855531    50.375786    50.643139    55.060945
# min      39.090000    40.000000    39.090000    39.500000    23.140000
# 25%      70.907500    71.387500    70.287500    70.937500    51.127500
# 50%      83.550000    84.215000    82.895000    83.595000    63.585000
# 75%     140.242500   141.257500   139.162500   140.467500   125.597500
# max     258.510000   259.770000   255.970000   258.630000   250.220000
#
#              Volume
# count  4.860000e+03
# mean   3.405795e+06
# std    1.920396e+06
# min    6.510000e+05
# 25%    2.208500e+06
# 50%    2.927350e+06
# 75%    4.023525e+06
# max    2.911600e+07

# %%
data.head(5)
# Out:
#              Open   High    Low  Close  Adj Close   Volume
# Date
# 1999-12-31  48.41  49.38  48.00  48.94      28.30  1021200
# 2000-01-03  48.03  48.25  47.03  47.19      27.29  2173400
# 2000-01-04  46.44  47.41  45.31  45.31      26.21  2713800
# 2000-01-05  45.56  48.12  45.56  46.62      26.97  3699400
# 2000-01-06  47.16  51.25  47.16  50.38      29.14  5975800

# %%
data.tail(5)
# Out:
#               Open    High     Low   Close  Adj Close    Volume
# Date
# 2019-04-22  217.30  219.40  217.27  218.54     218.54   1403500
# 2019-04-23  218.01  219.55  217.18  219.50     219.50   1561800
# 2019-04-24  219.00  219.75  218.10  219.08     219.08   2048900
# 2019-04-25  197.54  198.96  189.60  190.72     190.72  14646200
# 2019-04-26  190.53  192.25  189.36  191.67     191.67   4487500

# %%
import pandas as pd
import numpy as np
import datetime
import matplotlib.pyplot as plt
import plotly.graph_objs as go
% matplotlib inline

# %%
from plotly import __version__
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

print(__version__)
init_notebook_mode(connected=True)
# Out:
# 3.8.1
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
from pandas_datareader import data as pdr
import fix_yahoo_finance as yf
yf.pdr_override() # <== that's all it takes :-)
start_sp = datetime.datetime(2000, 1, 1)
end_sp = datetime.datetime(2019, 4, 29)
mmm = pdr.get_data_yahoo('MMM', 
                           start_sp,
                             end_sp)
    
mmm.head()
# Out:
# [*********************100%***********************]  1 of 1 downloaded
#              Open   High    Low  Close  Adj Close   Volume
# Date
# 1999-12-31  48.41  49.38  48.00  48.94      28.30  1021200
# 2000-01-03  48.03  48.25  47.03  47.19      27.29  2173400
# 2000-01-04  46.44  47.41  45.31  45.31      26.21  2713800
# 2000-01-05  45.56  48.12  45.56  46.62      26.97  3699400
# 2000-01-06  47.16  51.25  47.16  50.38      29.14  5975800

# %%
mmm.tail()
# Out:
#               Open    High     Low   Close  Adj Close    Volume
# Date
# 2019-04-22  217.30  219.40  217.27  218.54     218.54   1403500
# 2019-04-23  218.01  219.55  217.18  219.50     219.50   1561800
# 2019-04-24  219.00  219.75  218.10  219.08     219.08   2048900
# 2019-04-25  197.54  198.96  189.60  190.72     190.72  14646200
# 2019-04-26  190.53  192.25  189.36  191.67     191.67   4487500

# %%
portfolio_df = pd.read_excel('Sample stocks acquisition dates_costs.xlsx', sheet_name='Sample')
portfolio_df.head(10)
# Out:
#   Acquisition Date Ticker  Quantity  Unit Cost  Cost Basis Start of Year
# 0       2013-02-07   AAPL       125      65.40     8175.00    2017-12-29
# 1       2014-02-27    JNJ       100      81.90     8190.00    2017-12-29
# 2       2013-06-04    MCD       100      84.99     8499.00    2017-12-29
# 3       2015-12-14   MTCH       600      13.63     8178.00    2017-12-29
# 4       2016-01-14   NFLX        75     108.71     8153.25    2017-12-29
# 5       2013-08-14    WMT       125      68.30     8537.50    2017-12-29
# 6       2013-12-13     FB       150      53.32     7998.00    2017-12-29
# 7       2015-01-05   TWTR       225      36.38     8185.50    2017-12-29

# %%
# Generate a dynamic list of tickers to pull from Yahoo Finance API based on the imported file with tickers.
tickers = portfolio_df['Ticker'].unique()

# %%
# Stock comparison code
def get(ticker, startdate, enddate):
    def data(ticker):
        return (pdr.get_data_yahoo(ticker, start=startdate, end=enddate))
    datas = map(data, tickers)
    return pd.concat(datas, keys=tickers, names=['Ticker', 'Date'])

# %%
all_data = get(tickers, stocks_start, stocks_end)
all_data.tail()
# Out:
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
# [*********************100%***********************]  1 of 1 downloaded
#                     Open   High    Low  Close  Adj Close    Volume
# Ticker Date
# TWTR   2018-03-02  31.93  33.03  31.49  33.00      33.00  24918900
#        2018-03-05  32.90  34.95  32.58  34.58      34.58  34840000
#        2018-03-06  34.58  34.95  33.86  34.43      34.43  22641000
#        2018-03-07  33.99  35.82  33.99  35.76      35.76  33656100
#        2018-03-08  35.42  35.84  34.68  34.85      34.85  24845300

# %%
# Only pull ticker, date and adj. close columns for our tickers
adj_close = all_data[['Adj Close']].reset_index()
adj_close.head()
# Out:
#   Ticker       Date  Adj Close
# 0   AAPL 2012-12-31      53.97
# 1   AAPL 2013-01-02      55.68
# 2   AAPL 2013-01-03      54.98
# 3   AAPL 2013-01-04      53.45
# 4   AAPL 2013-01-07      53.14

# %%
# Grabbing the ticker close from the end of last year
end_of_last_year = datetime.datetime(2017, 12, 29)
adj_close_start = adj_close[adj_close['Date']==end_of_last_year]
adj_close_start.head()
# Out:
#      Ticker       Date  Adj Close
# 1259   AAPL 2017-12-29     166.01
# 2565    JNJ 2017-12-29     135.13
# 3871    MCD 2017-12-29     166.81
# 4449   MTCH 2017-12-29      29.80
# 5755   NFLX 2017-12-29     191.96

# %%
# Grab the latest stock close price
stocks_end = datetime.datetime(2018, 3, 8)
adj_close_latest = adj_close[adj_close['Date']==stocks_end]
adj_close_latest
# Out:
#      Ticker       Date  Adj Close
# 1305   AAPL 2018-03-08     174.29
# 2611    JNJ 2018-03-08     128.54
# 3917    MCD 2018-03-08     150.62
# 4495   MTCH 2018-03-08      42.22
# 5801   NFLX 2018-03-08     317.00
# 7107    WMT 2018-03-08      85.93
# 8413     FB 2018-03-08     182.34
# 9503   TWTR 2018-03-08      34.85

# %%
adj_close_latest.set_index('Ticker', inplace=True)
adj_close_latest.head()
# Out:
#              Date  Adj Close
# Ticker
# AAPL   2018-03-08     174.29
# JNJ    2018-03-08     128.54
# MCD    2018-03-08     150.62
# MTCH   2018-03-08      42.22
# NFLX   2018-03-08     317.00

# %%
# Set portfolio index prior to merging with the adj close latest.
portfolio_df
portfolio_df.set_index(['Ticker'], inplace=True)
portfolio_df.head()
# Out:
#        Acquisition Date  Quantity  Unit Cost  Cost Basis Start of Year
# Ticker
# AAPL         2013-02-07       125      65.40     8175.00    2017-12-29
# JNJ          2014-02-27       100      81.90     8190.00    2017-12-29
# MCD          2013-06-04       100      84.99     8499.00    2017-12-29
# MTCH         2015-12-14       600      13.63     8178.00    2017-12-29
# NFLX         2016-01-14        75     108.71     8153.25    2017-12-29

# %%
# Merge the portfolio dataframe with the adj close dataframe; they are being joined by their indexes.
merged_portfolio = pd.merge(portfolio_df, adj_close_latest, left_index=True, right_index=True)
merged_portfolio.head()
# Out:
#        Acquisition Date  Quantity  Unit Cost  Cost Basis Start of Year  \
# Ticker
# AAPL         2013-02-07       125      65.40     8175.00    2017-12-29
# JNJ          2014-02-27       100      81.90     8190.00    2017-12-29
# MCD          2013-06-04       100      84.99     8499.00    2017-12-29
# MTCH         2015-12-14       600      13.63     8178.00    2017-12-29
# NFLX         2016-01-14        75     108.71     8153.25    2017-12-29
#
#              Date  Adj Close
# Ticker
# AAPL   2018-03-08     174.29
# JNJ    2018-03-08     128.54
# MCD    2018-03-08     150.62
# MTCH   2018-03-08      42.22
# NFLX   2018-03-08     317.00

# %%
# The below creates a new column which is the ticker return; takes the latest adjusted close for each position
# and divides that by the initial share cost.
merged_portfolio['ticker return'] = merged_portfolio['Adj Close'] / merged_portfolio['Unit Cost'] - 1
merged_portfolio
# Out:
#        Acquisition Date  Quantity  Unit Cost  Cost Basis Start of Year  \
# Ticker
# AAPL         2013-02-07       125      65.40     8175.00    2017-12-29
# JNJ          2014-02-27       100      81.90     8190.00    2017-12-29
# MCD          2013-06-04       100      84.99     8499.00    2017-12-29
# MTCH         2015-12-14       600      13.63     8178.00    2017-12-29
# NFLX         2016-01-14        75     108.71     8153.25    2017-12-29
# WMT          2013-08-14       125      68.30     8537.50    2017-12-29
# FB           2013-12-13       150      53.32     7998.00    2017-12-29
# TWTR         2015-01-05       225      36.38     8185.50    2017-12-29
#
#              Date  Adj Close  ticker return
# Ticker
# AAPL   2018-03-08     174.29       1.664985
# JNJ    2018-03-08     128.54       0.569475
# MCD    2018-03-08     150.62       0.772208
# MTCH   2018-03-08      42.22       2.097579
# NFLX   2018-03-08     317.00       1.916015
# WMT    2018-03-08      85.93       0.258126
# FB     2018-03-08     182.34       2.419730
# TWTR   2018-03-08      34.85      -0.042056

# %%
sp500 = pdr.get_data_yahoo('^GSPC', 
                           start_sp,
                             end_sp)
    
sp500.head()
# Out:
# [*********************100%***********************]  1 of 1 downloaded
#                Open     High      Low    Close  Adj Close      Volume
# Date
# 1999-12-31  1464.47  1472.42  1458.19  1469.25    1469.25   374050000
# 2000-01-03  1469.25  1478.00  1438.36  1455.22    1455.22   931800000
# 2000-01-04  1455.22  1455.22  1397.43  1399.42    1399.42  1009000000
# 2000-01-05  1399.42  1413.27  1377.68  1402.11    1402.11  1085500000
# 2000-01-06  1402.11  1411.90  1392.10  1403.45    1403.45  1092300000

# %%
merged_portfolio.reset_index(inplace=True)
merged_portfolio.head()
# Out:
#    index Ticker Acquisition Date  Quantity  Unit Cost  Cost Basis  \
# 0      0   AAPL       2013-02-07       125      65.40     8175.00
# 1      1    JNJ       2014-02-27       100      81.90     8190.00
# 2      2    MCD       2013-06-04       100      84.99     8499.00
# 3      3   MTCH       2015-12-14       600      13.63     8178.00
# 4      4   NFLX       2016-01-14        75     108.71     8153.25
#
#   Start of Year       Date  Adj Close  ticker return
# 0    2017-12-29 2018-03-08     174.29       1.664985
# 1    2017-12-29 2018-03-08     128.54       0.569475
# 2    2017-12-29 2018-03-08     150.62       0.772208
# 3    2017-12-29 2018-03-08      42.22       2.097579
# 4    2017-12-29 2018-03-08     317.00       1.916015

# %%
merged_portfolio_sp = pd.merge(merged_portfolio, sp500[['Adj Close']], left_on='Acquisition Date', right_on='Date')

# %%
merged_portfolio_sp.head()
# Out:
#    index Ticker Acquisition Date  Quantity  Unit Cost  Cost Basis  \
# 0      0   AAPL       2013-02-07       125      65.40     8175.00
# 1      1    JNJ       2014-02-27       100      81.90     8190.00
# 2      2    MCD       2013-06-04       100      84.99     8499.00
# 3      3   MTCH       2015-12-14       600      13.63     8178.00
# 4      4   NFLX       2016-01-14        75     108.71     8153.25
#
#   Start of Year       Date  Adj Close_x  ticker return  Adj Close_y
# 0    2017-12-29 2018-03-08       174.29       1.664985      1509.39
# 1    2017-12-29 2018-03-08       128.54       0.569475      1854.29
# 2    2017-12-29 2018-03-08       150.62       0.772208      1631.38
# 3    2017-12-29 2018-03-08        42.22       2.097579      2021.94
# 4    2017-12-29 2018-03-08       317.00       1.916015      1921.84

# %%
merged_portfolio_sp.rename(columns={'Date': 'Latest Date', 'Adj Close_x': 'Ticker Adj Close'
                                    , 'Adj Close_y': 'SP 500 Initial Close'}, inplace=True)

# %%
merged_portfolio_sp
# Out:
#    index Ticker Acquisition Date  Quantity  Unit Cost  Cost Basis  \
# 0      0   AAPL       2013-02-07       125      65.40     8175.00
# 1      1    JNJ       2014-02-27       100      81.90     8190.00
# 2      2    MCD       2013-06-04       100      84.99     8499.00
# 3      3   MTCH       2015-12-14       600      13.63     8178.00
# 4      4   NFLX       2016-01-14        75     108.71     8153.25
# 5      5    WMT       2013-08-14       125      68.30     8537.50
# 6      6     FB       2013-12-13       150      53.32     7998.00
# 7      7   TWTR       2015-01-05       225      36.38     8185.50
#
#   Start of Year Latest Date  Ticker Adj Close  ticker return  \
# 0    2017-12-29  2018-03-08            174.29       1.664985
# 1    2017-12-29  2018-03-08            128.54       0.569475
# 2    2017-12-29  2018-03-08            150.62       0.772208
# 3    2017-12-29  2018-03-08             42.22       2.097579
# 4    2017-12-29  2018-03-08            317.00       1.916015
# 5    2017-12-29  2018-03-08             85.93       0.258126
# 6    2017-12-29  2018-03-08            182.34       2.419730
# 7    2017-12-29  2018-03-08             34.85      -0.042056
#
#    SP 500 Initial Close
# 0               1509.39
# 1               1854.29
# 2               1631.38
# 3               2021.94
# 4               1921.84
# 5               1685.39
# 6               1775.32
# 7               2020.58

# %%
# This new column determines what SP 500 equivalent purchase would have been at purchase date of stock.
merged_portfolio_sp['Equiv SP Shares'] = merged_portfolio_sp['Cost Basis'] / merged_portfolio_sp['SP 500 Initial Close']
merged_portfolio_sp.head()
# Out:
#    index Ticker Acquisition Date  Quantity  Unit Cost  Cost Basis  \
# 0      0   AAPL       2013-02-07       125      65.40     8175.00
# 1      1    JNJ       2014-02-27       100      81.90     8190.00
# 2      2    MCD       2013-06-04       100      84.99     8499.00
# 3      3   MTCH       2015-12-14       600      13.63     8178.00
# 4      4   NFLX       2016-01-14        75     108.71     8153.25
#
#   Start of Year Latest Date  Ticker Adj Close  ticker return  \
# 0    2017-12-29  2018-03-08            174.29       1.664985
# 1    2017-12-29  2018-03-08            128.54       0.569475
# 2    2017-12-29  2018-03-08            150.62       0.772208
# 3    2017-12-29  2018-03-08             42.22       2.097579
# 4    2017-12-29  2018-03-08            317.00       1.916015
#
#    SP 500 Initial Close  Equiv SP Shares
# 0               1509.39         5.416095
# 1               1854.29         4.416785
# 2               1631.38         5.209700
# 3               2021.94         4.044630
# 4               1921.84         4.242419

# %%
# We are joining the developing dataframe with the sp500 closes again, this time with the latest close for SP.
merged_portfolio_sp_latest = pd.merge(merged_portfolio_sp, sp500[['Adj Close']], left_on='Latest Date', right_on='Date')

# %%
merged_portfolio_sp_latest
# Out:
#    index Ticker Acquisition Date  Quantity  Unit Cost  Cost Basis  \
# 0      0   AAPL       2013-02-07       125      65.40     8175.00
# 1      1    JNJ       2014-02-27       100      81.90     8190.00
# 2      2    MCD       2013-06-04       100      84.99     8499.00
# 3      3   MTCH       2015-12-14       600      13.63     8178.00
# 4      4   NFLX       2016-01-14        75     108.71     8153.25
# 5      5    WMT       2013-08-14       125      68.30     8537.50
# 6      6     FB       2013-12-13       150      53.32     7998.00
# 7      7   TWTR       2015-01-05       225      36.38     8185.50
#
#   Start of Year Latest Date  Ticker Adj Close  ticker return  \
# 0    2017-12-29  2018-03-08            174.29       1.664985
# 1    2017-12-29  2018-03-08            128.54       0.569475
# 2    2017-12-29  2018-03-08            150.62       0.772208
# 3    2017-12-29  2018-03-08             42.22       2.097579
# 4    2017-12-29  2018-03-08            317.00       1.916015
# 5    2017-12-29  2018-03-08             85.93       0.258126
# 6    2017-12-29  2018-03-08            182.34       2.419730
# 7    2017-12-29  2018-03-08             34.85      -0.042056
#
#    SP 500 Initial Close  Equiv SP Shares  Adj Close
# 0               1509.39         5.416095    2738.97
# 1               1854.29         4.416785    2738.97
# 2               1631.38         5.209700    2738.97
# 3               2021.94         4.044630    2738.97
# 4               1921.84         4.242419    2738.97
# 5               1685.39         5.065593    2738.97
# 6               1775.32         4.505103    2738.97
# 7               2020.58         4.051065    2738.97

# %%
merged_portfolio_sp_latest.rename(columns={'Adj Close': 'SP 500 Latest Close'}, inplace=True)
merged_portfolio_sp_latest
# Out:
#    index Ticker Acquisition Date  Quantity  Unit Cost  Cost Basis  \
# 0      0   AAPL       2013-02-07       125      65.40     8175.00
# 1      1    JNJ       2014-02-27       100      81.90     8190.00
# 2      2    MCD       2013-06-04       100      84.99     8499.00
# 3      3   MTCH       2015-12-14       600      13.63     8178.00
# 4      4   NFLX       2016-01-14        75     108.71     8153.25
# 5      5    WMT       2013-08-14       125      68.30     8537.50
# 6      6     FB       2013-12-13       150      53.32     7998.00
# 7      7   TWTR       2015-01-05       225      36.38     8185.50
#
#   Start of Year Latest Date  Ticker Adj Close  ticker return  \
# 0    2017-12-29  2018-03-08            174.29       1.664985
# 1    2017-12-29  2018-03-08            128.54       0.569475
# 2    2017-12-29  2018-03-08            150.62       0.772208
# 3    2017-12-29  2018-03-08             42.22       2.097579
# 4    2017-12-29  2018-03-08            317.00       1.916015
# 5    2017-12-29  2018-03-08             85.93       0.258126
# 6    2017-12-29  2018-03-08            182.34       2.419730
# 7    2017-12-29  2018-03-08             34.85      -0.042056
#
#    SP 500 Initial Close  Equiv SP Shares  SP 500 Latest Close
# 0               1509.39         5.416095              2738.97
# 1               1854.29         4.416785              2738.97
# 2               1631.38         5.209700              2738.97
# 3               2021.94         4.044630              2738.97
# 4               1921.84         4.242419              2738.97
# 5               1685.39         5.065593              2738.97
# 6               1775.32         4.505103              2738.97
# 7               2020.58         4.051065              2738.97

# %%
# Percent return of SP from acquisition date of position through latest trading day.
merged_portfolio_sp_latest['SP Return'] = merged_portfolio_sp_latest['SP 500 Latest Close'] / merged_portfolio_sp_latest['SP 500 Initial Close'] - 1

# %%
merged_portfolio_sp_latest
# Out:
#    index Ticker Acquisition Date  Quantity  Unit Cost  Cost Basis  \
# 0      0   AAPL       2013-02-07       125      65.40     8175.00
# 1      1    JNJ       2014-02-27       100      81.90     8190.00
# 2      2    MCD       2013-06-04       100      84.99     8499.00
# 3      3   MTCH       2015-12-14       600      13.63     8178.00
# 4      4   NFLX       2016-01-14        75     108.71     8153.25
# 5      5    WMT       2013-08-14       125      68.30     8537.50
# 6      6     FB       2013-12-13       150      53.32     7998.00
# 7      7   TWTR       2015-01-05       225      36.38     8185.50
#
#   Start of Year Latest Date  Ticker Adj Close  ticker return  \
# 0    2017-12-29  2018-03-08            174.29       1.664985
# 1    2017-12-29  2018-03-08            128.54       0.569475
# 2    2017-12-29  2018-03-08            150.62       0.772208
# 3    2017-12-29  2018-03-08             42.22       2.097579
# 4    2017-12-29  2018-03-08            317.00       1.916015
# 5    2017-12-29  2018-03-08             85.93       0.258126
# 6    2017-12-29  2018-03-08            182.34       2.419730
# 7    2017-12-29  2018-03-08             34.85      -0.042056
#
#    SP 500 Initial Close  Equiv SP Shares  SP 500 Latest Close  SP Return
# 0               1509.39         5.416095              2738.97   0.814620
# 1               1854.29         4.416785              2738.97   0.477099
# 2               1631.38         5.209700              2738.97   0.678928
# 3               2021.94         4.044630              2738.97   0.354625
# 4               1921.84         4.242419              2738.97   0.425181
# 5               1685.39         5.065593              2738.97   0.625125
# 6               1775.32         4.505103              2738.97   0.542804
# 7               2020.58         4.051065              2738.97   0.355537

# %%
merged_portfolio_sp_latest['Abs. Return Compare'] = merged_portfolio_sp_latest['ticker return'] - merged_portfolio_sp_latest['SP Return']
merged_portfolio_sp_latest
# Out:
#    index Ticker Acquisition Date  Quantity  Unit Cost  Cost Basis  \
# 0      0   AAPL       2013-02-07       125      65.40     8175.00
# 1      1    JNJ       2014-02-27       100      81.90     8190.00
# 2      2    MCD       2013-06-04       100      84.99     8499.00
# 3      3   MTCH       2015-12-14       600      13.63     8178.00
# 4      4   NFLX       2016-01-14        75     108.71     8153.25
# 5      5    WMT       2013-08-14       125      68.30     8537.50
# 6      6     FB       2013-12-13       150      53.32     7998.00
# 7      7   TWTR       2015-01-05       225      36.38     8185.50
#
#   Start of Year Latest Date  Ticker Adj Close  ticker return  \
# 0    2017-12-29  2018-03-08            174.29       1.664985
# 1    2017-12-29  2018-03-08            128.54       0.569475
# 2    2017-12-29  2018-03-08            150.62       0.772208
# 3    2017-12-29  2018-03-08             42.22       2.097579
# 4    2017-12-29  2018-03-08            317.00       1.916015
# 5    2017-12-29  2018-03-08             85.93       0.258126
# 6    2017-12-29  2018-03-08            182.34       2.419730
# 7    2017-12-29  2018-03-08             34.85      -0.042056
#
#    SP 500 Initial Close  Equiv SP Shares  SP 500 Latest Close  SP Return  \
# 0               1509.39         5.416095              2738.97   0.814620
# 1               1854.29         4.416785              2738.97   0.477099
# 2               1631.38         5.209700              2738.97   0.678928
# 3               2021.94         4.044630              2738.97   0.354625
# 4               1921.84         4.242419              2738.97   0.425181
# 5               1685.39         5.065593              2738.97   0.625125
# 6               1775.32         4.505103              2738.97   0.542804
# 7               2020.58         4.051065              2738.97   0.355537
#
#    Abs. Return Compare
# 0             0.850364
# 1             0.092376
# 2             0.093280
# 3             1.742954
# 4             1.490834
# 5            -0.366999
# 6             1.876926
# 7            -0.397593

# %%
merged_portfolio_sp_latest['Ticker Share Value'] = merged_portfolio_sp_latest['Quantity'] * merged_portfolio_sp_latest['Ticker Adj Close']
merged_portfolio_sp_latest
# Out:
#    index Ticker Acquisition Date  Quantity  Unit Cost  Cost Basis  \
# 0      0   AAPL       2013-02-07       125      65.40     8175.00
# 1      1    JNJ       2014-02-27       100      81.90     8190.00
# 2      2    MCD       2013-06-04       100      84.99     8499.00
# 3      3   MTCH       2015-12-14       600      13.63     8178.00
# 4      4   NFLX       2016-01-14        75     108.71     8153.25
# 5      5    WMT       2013-08-14       125      68.30     8537.50
# 6      6     FB       2013-12-13       150      53.32     7998.00
# 7      7   TWTR       2015-01-05       225      36.38     8185.50
#
#   Start of Year Latest Date  Ticker Adj Close  ticker return  \
# 0    2017-12-29  2018-03-08            174.29       1.664985
# 1    2017-12-29  2018-03-08            128.54       0.569475
# 2    2017-12-29  2018-03-08            150.62       0.772208
# 3    2017-12-29  2018-03-08             42.22       2.097579
# 4    2017-12-29  2018-03-08            317.00       1.916015
# 5    2017-12-29  2018-03-08             85.93       0.258126
# 6    2017-12-29  2018-03-08            182.34       2.419730
# 7    2017-12-29  2018-03-08             34.85      -0.042056
#
#    SP 500 Initial Close  Equiv SP Shares  SP 500 Latest Close  SP Return  \
# 0               1509.39         5.416095              2738.97   0.814620
# 1               1854.29         4.416785              2738.97   0.477099
# 2               1631.38         5.209700              2738.97   0.678928
# 3               2021.94         4.044630              2738.97   0.354625
# 4               1921.84         4.242419              2738.97   0.425181
# 5               1685.39         5.065593              2738.97   0.625125
# 6               1775.32         4.505103              2738.97   0.542804
# 7               2020.58         4.051065              2738.97   0.355537
#
#    Abs. Return Compare  Ticker Share Value
# 0             0.850364            21786.25
# 1             0.092376            12854.00
# 2             0.093280            15062.00
# 3             1.742954            25332.00
# 4             1.490834            23775.00
# 5            -0.366999            10741.25
# 6             1.876926            27351.00
# 7            -0.397593             7841.25

# %%
# We calculate the equivalent SP 500 Value if we take the original SP shares * the latest SP 500 share price.
merged_portfolio_sp_latest['SP 500 Value'] = merged_portfolio_sp_latest['Equiv SP Shares'] * merged_portfolio_sp_latest['SP 500 Latest Close']
# This is a new column where we take the current market value for the shares and subtract the SP 500 value.
merged_portfolio_sp_latest['Abs Value Compare'] = merged_portfolio_sp_latest['Ticker Share Value'] - merged_portfolio_sp_latest['SP 500 Value']
# This column calculates profit / loss for stock position.
merged_portfolio_sp_latest['Stock Gain / (Loss)'] = merged_portfolio_sp_latest['Ticker Share Value'] - merged_portfolio_sp_latest['Cost Basis']
# This column calculates profit / loss for SP 500.
merged_portfolio_sp_latest['SP 500 Gain / (Loss)'] = merged_portfolio_sp_latest['SP 500 Value'] - merged_portfolio_sp_latest['Cost Basis']
merged_portfolio_sp_latest
# Out:
#    index Ticker Acquisition Date  Quantity  Unit Cost  Cost Basis  \
# 0      0   AAPL       2013-02-07       125      65.40     8175.00
# 1      1    JNJ       2014-02-27       100      81.90     8190.00
# 2      2    MCD       2013-06-04       100      84.99     8499.00
# 3      3   MTCH       2015-12-14       600      13.63     8178.00
# 4      4   NFLX       2016-01-14        75     108.71     8153.25
# 5      5    WMT       2013-08-14       125      68.30     8537.50
# 6      6     FB       2013-12-13       150      53.32     7998.00
# 7      7   TWTR       2015-01-05       225      36.38     8185.50
#
#   Start of Year Latest Date  Ticker Adj Close  ticker return  \
# 0    2017-12-29  2018-03-08            174.29       1.664985
# 1    2017-12-29  2018-03-08            128.54       0.569475
# 2    2017-12-29  2018-03-08            150.62       0.772208
# 3    2017-12-29  2018-03-08             42.22       2.097579
# 4    2017-12-29  2018-03-08            317.00       1.916015
# 5    2017-12-29  2018-03-08             85.93       0.258126
# 6    2017-12-29  2018-03-08            182.34       2.419730
# 7    2017-12-29  2018-03-08             34.85      -0.042056
#
#    SP 500 Initial Close  Equiv SP Shares  SP 500 Latest Close  SP Return  \
# 0               1509.39         5.416095              2738.97   0.814620
# 1               1854.29         4.416785              2738.97   0.477099
# 2               1631.38         5.209700              2738.97   0.678928
# 3               2021.94         4.044630              2738.97   0.354625
# 4               1921.84         4.242419              2738.97   0.425181
# 5               1685.39         5.065593              2738.97   0.625125
# 6               1775.32         4.505103              2738.97   0.542804
# 7               2020.58         4.051065              2738.97   0.355537
#
#    Abs. Return Compare  Ticker Share Value  SP 500 Value  Abs Value Compare  \
# 0             0.850364            21786.25  14834.522390        6951.727610
# 1             0.092376            12854.00  12097.441231         756.558769
# 2             0.093280            15062.00  14269.211361         792.788639
# 3             1.742954            25332.00  11078.121339       14253.878661
# 4             1.490834            23775.00  11619.857612       12155.142388
# 5            -0.366999            10741.25  13874.507607       -3133.257607
# 6             1.876926            27351.00  12339.342800       15011.657200
# 7            -0.397593             7841.25  11095.744259       -3254.494259
#
#    Stock Gain / (Loss)  SP 500 Gain / (Loss)
# 0             13611.25           6659.522390
# 1              4664.00           3907.441231
# 2              6563.00           5770.211361
# 3             17154.00           2900.121339
# 4             15621.75           3466.607612
# 5              2203.75           5337.007607
# 6             19353.00           4341.342800
# 7              -344.25           2910.244259

# %%
adj_close_start.head()
# Out:
#      Ticker       Date  Adj Close
# 1259   AAPL 2017-12-29     166.01
# 2565    JNJ 2017-12-29     135.13
# 3871    MCD 2017-12-29     166.81
# 4449   MTCH 2017-12-29      29.80
# 5755   NFLX 2017-12-29     191.96

# %%
# Merge the overall dataframe with the adj close start of year dataframe for YTD tracking of tickers.
merged_portfolio_sp_latest_YTD = pd.merge(merged_portfolio_sp_latest, adj_close_start, on='Ticker')
merged_portfolio_sp_latest_YTD
# Out:
#    index Ticker Acquisition Date  Quantity  Unit Cost  Cost Basis  \
# 0      0   AAPL       2013-02-07       125      65.40     8175.00
# 1      1    JNJ       2014-02-27       100      81.90     8190.00
# 2      2    MCD       2013-06-04       100      84.99     8499.00
# 3      3   MTCH       2015-12-14       600      13.63     8178.00
# 4      4   NFLX       2016-01-14        75     108.71     8153.25
# 5      5    WMT       2013-08-14       125      68.30     8537.50
# 6      6     FB       2013-12-13       150      53.32     7998.00
# 7      7   TWTR       2015-01-05       225      36.38     8185.50
#
#   Start of Year Latest Date  Ticker Adj Close  ticker return    ...      \
# 0    2017-12-29  2018-03-08            174.29       1.664985    ...
# 1    2017-12-29  2018-03-08            128.54       0.569475    ...
# 2    2017-12-29  2018-03-08            150.62       0.772208    ...
# 3    2017-12-29  2018-03-08             42.22       2.097579    ...
# 4    2017-12-29  2018-03-08            317.00       1.916015    ...
# 5    2017-12-29  2018-03-08             85.93       0.258126    ...
# 6    2017-12-29  2018-03-08            182.34       2.419730    ...
# 7    2017-12-29  2018-03-08             34.85      -0.042056    ...
#
#    SP 500 Latest Close  SP Return  Abs. Return Compare  Ticker Share Value  \
# 0              2738.97   0.814620             0.850364            21786.25
# 1              2738.97   0.477099             0.092376            12854.00
# 2              2738.97   0.678928             0.093280            15062.00
# 3              2738.97   0.354625             1.742954            25332.00
# 4              2738.97   0.425181             1.490834            23775.00
# 5              2738.97   0.625125            -0.366999            10741.25
# 6              2738.97   0.542804             1.876926            27351.00
# 7              2738.97   0.355537            -0.397593             7841.25
#
#    SP 500 Value  Abs Value Compare  Stock Gain / (Loss)  SP 500 Gain / (Loss)  \
# 0  14834.522390        6951.727610             13611.25           6659.522390
# 1  12097.441231         756.558769              4664.00           3907.441231
# 2  14269.211361         792.788639              6563.00           5770.211361
# 3  11078.121339       14253.878661             17154.00           2900.121339
# 4  11619.857612       12155.142388             15621.75           3466.607612
# 5  13874.507607       -3133.257607              2203.75           5337.007607
# 6  12339.342800       15011.657200             19353.00           4341.342800
# 7  11095.744259       -3254.494259              -344.25           2910.244259
#
#         Date  Adj Close
# 0 2017-12-29     166.01
# 1 2017-12-29     135.13
# 2 2017-12-29     166.81
# 3 2017-12-29      29.80
# 4 2017-12-29     191.96
# 5 2017-12-29      95.94
# 6 2017-12-29     176.46
# 7 2017-12-29      24.01
#
# [8 rows x 22 columns]

# %%
merged_portfolio_sp_latest_YTD.rename(columns={'Adj Close': 'Ticker Start Year Close'}, inplace=True)

# %%
sp500.reset_index(inplace=True)
sp_500_adj_close_start = sp500[sp500['Date']==end_of_last_year]

# %%
sp_500_adj_close_start
# Out:
#       index       Date     Open     High      Low    Close  Adj Close  \
# 4528   4528 2017-12-29  2689.15  2692.12  2673.61  2673.61    2673.61
#
#           Volume
# 4528  2443490000

# %%
merged_portfolio_sp_latest_YTD_sp.drop(merged_portfolio_sp_latest_YTD_sp.iloc[:, 22:30], axis=1, inplace=True)

# %%
merged_portfolio_sp_latest_YTD_sp
# Out:
#    index_x Ticker Acquisition Date  Quantity  Unit Cost  Cost Basis  \
# 0        0   AAPL       2013-02-07       125      65.40     8175.00
# 1        1    JNJ       2014-02-27       100      81.90     8190.00
# 2        2    MCD       2013-06-04       100      84.99     8499.00
# 3        3   MTCH       2015-12-14       600      13.63     8178.00
# 4        4   NFLX       2016-01-14        75     108.71     8153.25
# 5        5    WMT       2013-08-14       125      68.30     8537.50
# 6        6     FB       2013-12-13       150      53.32     7998.00
# 7        7   TWTR       2015-01-05       225      36.38     8185.50
#
#   Start of Year Latest Date  Ticker Adj Close  ticker return  \
# 0    2017-12-29  2018-03-08            174.29       1.664985
# 1    2017-12-29  2018-03-08            128.54       0.569475
# 2    2017-12-29  2018-03-08            150.62       0.772208
# 3    2017-12-29  2018-03-08             42.22       2.097579
# 4    2017-12-29  2018-03-08            317.00       1.916015
# 5    2017-12-29  2018-03-08             85.93       0.258126
# 6    2017-12-29  2018-03-08            182.34       2.419730
# 7    2017-12-29  2018-03-08             34.85      -0.042056
#
#             ...             SP 500 Latest Close  SP Return  \
# 0           ...                         2738.97   0.814620
# 1           ...                         2738.97   0.477099
# 2           ...                         2738.97   0.678928
# 3           ...                         2738.97   0.354625
# 4           ...                         2738.97   0.425181
# 5           ...                         2738.97   0.625125
# 6           ...                         2738.97   0.542804
# 7           ...                         2738.97   0.355537
#
#    Abs. Return Compare  Ticker Share Value  SP 500 Value  Abs Value Compare  \
# 0             0.850364            21786.25  14834.522390        6951.727610
# 1             0.092376            12854.00  12097.441231         756.558769
# 2             0.093280            15062.00  14269.211361         792.788639
# 3             1.742954            25332.00  11078.121339       14253.878661
# 4             1.490834            23775.00  11619.857612       12155.142388
# 5            -0.366999            10741.25  13874.507607       -3133.257607
# 6             1.876926            27351.00  12339.342800       15011.657200
# 7            -0.397593             7841.25  11095.744259       -3254.494259
#
#    Stock Gain / (Loss)  SP 500 Gain / (Loss)     Date_x  \
# 0             13611.25           6659.522390 2017-12-29
# 1              4664.00           3907.441231 2017-12-29
# 2              6563.00           5770.211361 2017-12-29
# 3             17154.00           2900.121339 2017-12-29
# 4             15621.75           3466.607612 2017-12-29
# 5              2203.75           5337.007607 2017-12-29
# 6             19353.00           4341.342800 2017-12-29
# 7              -344.25           2910.244259 2017-12-29
#
#    Ticker Start Year Close
# 0                   166.01
# 1                   135.13
# 2                   166.81
# 3                    29.80
# 4                   191.96
# 5                    95.94
# 6                   176.46
# 7                    24.01
#
# [8 rows x 22 columns]

# %%
merged_portfolio_sp_latest_YTD_sp.describe()
# Out:
#        index_x   Quantity   Unit Cost   Cost Basis  Ticker Adj Close  \
# count  8.00000    8.00000    8.000000     8.000000          8.000000
# mean   3.50000  187.50000   64.078750  8239.531250        139.473750
# std    2.44949  172.68882   29.747601   183.308602         91.088964
# min    0.00000   75.00000   13.630000  7998.000000         34.850000
# 25%    1.75000  100.00000   49.085000  8169.562500         75.002500
# 50%    3.50000  125.00000   66.850000  8181.750000        139.580000
# 75%    5.25000  168.75000   82.672500  8267.250000        176.302500
# max    7.00000  600.00000  108.710000  8537.500000        317.000000
#
#        ticker return  SP 500 Initial Close  Equiv SP Shares  \
# count       8.000000               8.00000         8.000000
# mean        1.207008            1802.51625         4.618924
# std         0.928307             186.04380         0.538763
# min        -0.042056            1509.39000         4.044630
# 25%         0.491638            1671.88750         4.194580
# 50%         1.218597            1814.80500         4.460944
# 75%         1.961406            1946.52500         5.101620
# max         2.419730            2021.94000         5.416095
#
#        SP 500 Latest Close  SP Return  Abs. Return Compare  \
# count                 8.00   8.000000             8.000000
# mean               2738.97   0.534240             0.672768
# std                   0.00   0.163549             0.940784
# min                2738.97   0.354625            -0.397593
# 25%                2738.97   0.407770            -0.022468
# 50%                2738.97   0.509951             0.471822
# 75%                2738.97   0.638576             1.553864
# max                2738.97   0.814620             1.876926
#
#        Ticker Share Value  SP 500 Value  Abs Value Compare  \
# count            8.000000      8.000000           8.000000
# mean         18092.843750  12651.093575        5441.750175
# std           7366.134793   1475.656206        7646.714359
# min           7841.250000  11078.121339       -3254.494259
# 25%          12325.812500  11488.829274        -215.895325
# 50%          18424.125000  12218.392016        3872.258125
# 75%          24164.250000  13973.183545       12679.826456
# max          27351.000000  14834.522390       15011.657200
#
#        Stock Gain / (Loss)  SP 500 Gain / (Loss)  Ticker Start Year Close
# count             8.000000              8.000000                 8.000000
# mean           9853.312500           4411.562325               123.265000
# std            7475.696565           1385.956023                66.275085
# min            -344.250000           2900.121339                24.010000
# 25%            4048.937500           3327.516774                79.405000
# 50%           10087.125000           4124.392016               150.570000
# 75%           16004.812500           5445.308545               169.222500
# max           19353.000000           6659.522390               191.960000

# %%
merged_portfolio_sp_latest_YTD_sp.columns
# Out:
# Index(['index_x', 'Ticker', 'Acquisition Date', 'Quantity', 'Unit Cost',
#        'Cost Basis', 'Start of Year', 'Latest Date', 'Ticker Adj Close',
#        'ticker return', 'SP 500 Initial Close', 'Equiv SP Shares',
#        'SP 500 Latest Close', 'SP Return', 'Abs. Return Compare',
#        'Ticker Share Value', 'SP 500 Value', 'Abs Value Compare',
#        'Stock Gain / (Loss)', 'SP 500 Gain / (Loss)', 'Date_x',
#        'Ticker Start Year Close'],
#       dtype='object')

# %%
merged_portfolio_sp_latest_YTD_sp.rename(columns={'index_x': 'index', 'Date_x': 'Date'}, inplace=True)

# %%
merged_portfolio_sp_latest_YTD_sp
# Out:
#    index Ticker Acquisition Date  Quantity  Unit Cost  Cost Basis  \
# 0      0   AAPL       2013-02-07       125      65.40     8175.00
# 1      1    JNJ       2014-02-27       100      81.90     8190.00
# 2      2    MCD       2013-06-04       100      84.99     8499.00
# 3      3   MTCH       2015-12-14       600      13.63     8178.00
# 4      4   NFLX       2016-01-14        75     108.71     8153.25
# 5      5    WMT       2013-08-14       125      68.30     8537.50
# 6      6     FB       2013-12-13       150      53.32     7998.00
# 7      7   TWTR       2015-01-05       225      36.38     8185.50
#
#   Start of Year Latest Date  Ticker Adj Close  ticker return  \
# 0    2017-12-29  2018-03-08            174.29       1.664985
# 1    2017-12-29  2018-03-08            128.54       0.569475
# 2    2017-12-29  2018-03-08            150.62       0.772208
# 3    2017-12-29  2018-03-08             42.22       2.097579
# 4    2017-12-29  2018-03-08            317.00       1.916015
# 5    2017-12-29  2018-03-08             85.93       0.258126
# 6    2017-12-29  2018-03-08            182.34       2.419730
# 7    2017-12-29  2018-03-08             34.85      -0.042056
#
#             ...             SP 500 Latest Close  SP Return  \
# 0           ...                         2738.97   0.814620
# 1           ...                         2738.97   0.477099
# 2           ...                         2738.97   0.678928
# 3           ...                         2738.97   0.354625
# 4           ...                         2738.97   0.425181
# 5           ...                         2738.97   0.625125
# 6           ...                         2738.97   0.542804
# 7           ...                         2738.97   0.355537
#
#    Abs. Return Compare  Ticker Share Value  SP 500 Value  Abs Value Compare  \
# 0             0.850364            21786.25  14834.522390        6951.727610
# 1             0.092376            12854.00  12097.441231         756.558769
# 2             0.093280            15062.00  14269.211361         792.788639
# 3             1.742954            25332.00  11078.121339       14253.878661
# 4             1.490834            23775.00  11619.857612       12155.142388
# 5            -0.366999            10741.25  13874.507607       -3133.257607
# 6             1.876926            27351.00  12339.342800       15011.657200
# 7            -0.397593             7841.25  11095.744259       -3254.494259
#
#    Stock Gain / (Loss)  SP 500 Gain / (Loss)       Date  \
# 0             13611.25           6659.522390 2017-12-29
# 1              4664.00           3907.441231 2017-12-29
# 2              6563.00           5770.211361 2017-12-29
# 3             17154.00           2900.121339 2017-12-29
# 4             15621.75           3466.607612 2017-12-29
# 5              2203.75           5337.007607 2017-12-29
# 6             19353.00           4341.342800 2017-12-29
# 7              -344.25           2910.244259 2017-12-29
#
#    Ticker Start Year Close
# 0                   166.01
# 1                   135.13
# 2                   166.81
# 3                    29.80
# 4                   191.96
# 5                    95.94
# 6                   176.46
# 7                    24.01
#
# [8 rows x 22 columns]

# %%
merged_portfolio_sp_latest_YTD_sp = pd.merge(merged_portfolio_sp_latest_YTD, sp_500_adj_close_start[['Date', 'Adj Close']]
                                             , left_on='Start of Year', right_on='Date')

# %%
merged_portfolio_sp_latest_YTD_sp
# Out:
#    index Ticker Acquisition Date  Quantity  Unit Cost  Cost Basis  \
# 0      0   AAPL       2013-02-07       125      65.40     8175.00
# 1      1    JNJ       2014-02-27       100      81.90     8190.00
# 2      2    MCD       2013-06-04       100      84.99     8499.00
# 3      3   MTCH       2015-12-14       600      13.63     8178.00
# 4      4   NFLX       2016-01-14        75     108.71     8153.25
# 5      5    WMT       2013-08-14       125      68.30     8537.50
# 6      6     FB       2013-12-13       150      53.32     7998.00
# 7      7   TWTR       2015-01-05       225      36.38     8185.50
#
#   Start of Year Latest Date  Ticker Adj Close  ticker return    ...      \
# 0    2017-12-29  2018-03-08            174.29       1.664985    ...
# 1    2017-12-29  2018-03-08            128.54       0.569475    ...
# 2    2017-12-29  2018-03-08            150.62       0.772208    ...
# 3    2017-12-29  2018-03-08             42.22       2.097579    ...
# 4    2017-12-29  2018-03-08            317.00       1.916015    ...
# 5    2017-12-29  2018-03-08             85.93       0.258126    ...
# 6    2017-12-29  2018-03-08            182.34       2.419730    ...
# 7    2017-12-29  2018-03-08             34.85      -0.042056    ...
#
#    Abs. Return Compare  Ticker Share Value  SP 500 Value  Abs Value Compare  \
# 0             0.850364            21786.25  14834.522390        6951.727610
# 1             0.092376            12854.00  12097.441231         756.558769
# 2             0.093280            15062.00  14269.211361         792.788639
# 3             1.742954            25332.00  11078.121339       14253.878661
# 4             1.490834            23775.00  11619.857612       12155.142388
# 5            -0.366999            10741.25  13874.507607       -3133.257607
# 6             1.876926            27351.00  12339.342800       15011.657200
# 7            -0.397593             7841.25  11095.744259       -3254.494259
#
#    Stock Gain / (Loss)  SP 500 Gain / (Loss)     Date_x  \
# 0             13611.25           6659.522390 2017-12-29
# 1              4664.00           3907.441231 2017-12-29
# 2              6563.00           5770.211361 2017-12-29
# 3             17154.00           2900.121339 2017-12-29
# 4             15621.75           3466.607612 2017-12-29
# 5              2203.75           5337.007607 2017-12-29
# 6             19353.00           4341.342800 2017-12-29
# 7              -344.25           2910.244259 2017-12-29
#
#    Ticker Start Year Close     Date_y  Adj Close
# 0                   166.01 2017-12-29    2673.61
# 1                   135.13 2017-12-29    2673.61
# 2                   166.81 2017-12-29    2673.61
# 3                    29.80 2017-12-29    2673.61
# 4                   191.96 2017-12-29    2673.61
# 5                    95.94 2017-12-29    2673.61
# 6                   176.46 2017-12-29    2673.61
# 7                    24.01 2017-12-29    2673.61
#
# [8 rows x 24 columns]

# %%
merged_portfolio_sp_latest_YTD_sp
# Out:
#    index Ticker Acquisition Date  Quantity  Unit Cost  Cost Basis  \
# 0      0   AAPL       2013-02-07       125      65.40     8175.00
# 1      1    JNJ       2014-02-27       100      81.90     8190.00
# 2      2    MCD       2013-06-04       100      84.99     8499.00
# 3      3   MTCH       2015-12-14       600      13.63     8178.00
# 4      4   NFLX       2016-01-14        75     108.71     8153.25
# 5      5    WMT       2013-08-14       125      68.30     8537.50
# 6      6     FB       2013-12-13       150      53.32     7998.00
# 7      7   TWTR       2015-01-05       225      36.38     8185.50
#
#   Start of Year Latest Date  Ticker Adj Close  ticker return    ...      \
# 0    2017-12-29  2018-03-08            174.29       1.664985    ...
# 1    2017-12-29  2018-03-08            128.54       0.569475    ...
# 2    2017-12-29  2018-03-08            150.62       0.772208    ...
# 3    2017-12-29  2018-03-08             42.22       2.097579    ...
# 4    2017-12-29  2018-03-08            317.00       1.916015    ...
# 5    2017-12-29  2018-03-08             85.93       0.258126    ...
# 6    2017-12-29  2018-03-08            182.34       2.419730    ...
# 7    2017-12-29  2018-03-08             34.85      -0.042056    ...
#
#    SP Return  Abs. Return Compare  Ticker Share Value  SP 500 Value  \
# 0   0.814620             0.850364            21786.25  14834.522390
# 1   0.477099             0.092376            12854.00  12097.441231
# 2   0.678928             0.093280            15062.00  14269.211361
# 3   0.354625             1.742954            25332.00  11078.121339
# 4   0.425181             1.490834            23775.00  11619.857612
# 5   0.625125            -0.366999            10741.25  13874.507607
# 6   0.542804             1.876926            27351.00  12339.342800
# 7   0.355537            -0.397593             7841.25  11095.744259
#
#    Abs Value Compare  Stock Gain / (Loss)  SP 500 Gain / (Loss)     Date_x  \
# 0        6951.727610             13611.25           6659.522390 2017-12-29
# 1         756.558769              4664.00           3907.441231 2017-12-29
# 2         792.788639              6563.00           5770.211361 2017-12-29
# 3       14253.878661             17154.00           2900.121339 2017-12-29
# 4       12155.142388             15621.75           3466.607612 2017-12-29
# 5       -3133.257607              2203.75           5337.007607 2017-12-29
# 6       15011.657200             19353.00           4341.342800 2017-12-29
# 7       -3254.494259              -344.25           2910.244259 2017-12-29
#
#    Ticker Start Year Close  Adj Close
# 0                   166.01    2673.61
# 1                   135.13    2673.61
# 2                   166.81    2673.61
# 3                    29.80    2673.61
# 4                   191.96    2673.61
# 5                    95.94    2673.61
# 6                   176.46    2673.61
# 7                    24.01    2673.61
#
# [8 rows x 23 columns]

# %%
del merged_portfolio_sp_latest_YTD_sp['Date_x']

# %%
merged_portfolio_sp_latest_YTD_sp
# Out:
#    index Ticker Acquisition Date  Quantity  Unit Cost  Cost Basis  \
# 0      0   AAPL       2013-02-07       125      65.40     8175.00
# 1      1    JNJ       2014-02-27       100      81.90     8190.00
# 2      2    MCD       2013-06-04       100      84.99     8499.00
# 3      3   MTCH       2015-12-14       600      13.63     8178.00
# 4      4   NFLX       2016-01-14        75     108.71     8153.25
# 5      5    WMT       2013-08-14       125      68.30     8537.50
# 6      6     FB       2013-12-13       150      53.32     7998.00
# 7      7   TWTR       2015-01-05       225      36.38     8185.50
#
#   Start of Year Latest Date  Ticker Adj Close  ticker return    ...      \
# 0    2017-12-29  2018-03-08            174.29       1.664985    ...
# 1    2017-12-29  2018-03-08            128.54       0.569475    ...
# 2    2017-12-29  2018-03-08            150.62       0.772208    ...
# 3    2017-12-29  2018-03-08             42.22       2.097579    ...
# 4    2017-12-29  2018-03-08            317.00       1.916015    ...
# 5    2017-12-29  2018-03-08             85.93       0.258126    ...
# 6    2017-12-29  2018-03-08            182.34       2.419730    ...
# 7    2017-12-29  2018-03-08             34.85      -0.042056    ...
#
#    SP 500 Latest Close  SP Return  Abs. Return Compare  Ticker Share Value  \
# 0              2738.97   0.814620             0.850364            21786.25
# 1              2738.97   0.477099             0.092376            12854.00
# 2              2738.97   0.678928             0.093280            15062.00
# 3              2738.97   0.354625             1.742954            25332.00
# 4              2738.97   0.425181             1.490834            23775.00
# 5              2738.97   0.625125            -0.366999            10741.25
# 6              2738.97   0.542804             1.876926            27351.00
# 7              2738.97   0.355537            -0.397593             7841.25
#
#    SP 500 Value  Abs Value Compare  Stock Gain / (Loss)  SP 500 Gain / (Loss)  \
# 0  14834.522390        6951.727610             13611.25           6659.522390
# 1  12097.441231         756.558769              4664.00           3907.441231
# 2  14269.211361         792.788639              6563.00           5770.211361
# 3  11078.121339       14253.878661             17154.00           2900.121339
# 4  11619.857612       12155.142388             15621.75           3466.607612
# 5  13874.507607       -3133.257607              2203.75           5337.007607
# 6  12339.342800       15011.657200             19353.00           4341.342800
# 7  11095.744259       -3254.494259              -344.25           2910.244259
#
#    Ticker Start Year Close  Adj Close
# 0                   166.01    2673.61
# 1                   135.13    2673.61
# 2                   166.81    2673.61
# 3                    29.80    2673.61
# 4                   191.96    2673.61
# 5                    95.94    2673.61
# 6                   176.46    2673.61
# 7                    24.01    2673.61
#
# [8 rows x 22 columns]

# %%
merged_portfolio_sp_latest_YTD_sp.rename(columns={'Adj Close': 'SP Start Year Close'}, inplace=True)

# %%
# YTD return for portfolio position.
merged_portfolio_sp_latest_YTD_sp['Share YTD'] = merged_portfolio_sp_latest_YTD_sp['Ticker Adj Close'] / merged_portfolio_sp_latest_YTD_sp['Ticker Start Year Close'] - 1
# YTD return for SP to run compares.
merged_portfolio_sp_latest_YTD_sp['SP 500 YTD'] = merged_portfolio_sp_latest_YTD_sp['SP 500 Latest Close'] / merged_portfolio_sp_latest_YTD_sp['SP Start Year Close'] - 1

# %%
merged_portfolio_sp_latest_YTD_sp
# Out:
#    index Ticker Acquisition Date  Quantity  Unit Cost  Cost Basis  \
# 0      0   AAPL       2013-02-07       125      65.40     8175.00
# 1      1    JNJ       2014-02-27       100      81.90     8190.00
# 2      2    MCD       2013-06-04       100      84.99     8499.00
# 3      3   MTCH       2015-12-14       600      13.63     8178.00
# 4      4   NFLX       2016-01-14        75     108.71     8153.25
# 5      5    WMT       2013-08-14       125      68.30     8537.50
# 6      6     FB       2013-12-13       150      53.32     7998.00
# 7      7   TWTR       2015-01-05       225      36.38     8185.50
#
#   Start of Year Latest Date  Ticker Adj Close  ticker return     ...      \
# 0    2017-12-29  2018-03-08            174.29       1.664985     ...
# 1    2017-12-29  2018-03-08            128.54       0.569475     ...
# 2    2017-12-29  2018-03-08            150.62       0.772208     ...
# 3    2017-12-29  2018-03-08             42.22       2.097579     ...
# 4    2017-12-29  2018-03-08            317.00       1.916015     ...
# 5    2017-12-29  2018-03-08             85.93       0.258126     ...
# 6    2017-12-29  2018-03-08            182.34       2.419730     ...
# 7    2017-12-29  2018-03-08             34.85      -0.042056     ...
#
#    Abs. Return Compare  Ticker Share Value  SP 500 Value  Abs Value Compare  \
# 0             0.850364            21786.25  14834.522390        6951.727610
# 1             0.092376            12854.00  12097.441231         756.558769
# 2             0.093280            15062.00  14269.211361         792.788639
# 3             1.742954            25332.00  11078.121339       14253.878661
# 4             1.490834            23775.00  11619.857612       12155.142388
# 5            -0.366999            10741.25  13874.507607       -3133.257607
# 6             1.876926            27351.00  12339.342800       15011.657200
# 7            -0.397593             7841.25  11095.744259       -3254.494259
#
#    Stock Gain / (Loss)  SP 500 Gain / (Loss)  Ticker Start Year Close  \
# 0             13611.25           6659.522390                   166.01
# 1              4664.00           3907.441231                   135.13
# 2              6563.00           5770.211361                   166.81
# 3             17154.00           2900.121339                    29.80
# 4             15621.75           3466.607612                   191.96
# 5              2203.75           5337.007607                    95.94
# 6             19353.00           4341.342800                   176.46
# 7              -344.25           2910.244259                    24.01
#
#    SP Start Year Close  Share YTD  SP 500 YTD
# 0              2673.61   0.049877    0.024446
# 1              2673.61  -0.048768    0.024446
# 2              2673.61  -0.097057    0.024446
# 3              2673.61   0.416779    0.024446
# 4              2673.61   0.651386    0.024446
# 5              2673.61  -0.104336    0.024446
# 6              2673.61   0.033322    0.024446
# 7              2673.61   0.451479    0.024446
#
# [8 rows x 24 columns]

# %%
merged_portfolio_sp_latest_YTD_sp = merged_portfolio_sp_latest_YTD_sp.sort_values(by='Ticker', ascending=True)

# %%
merged_portfolio_sp_latest_YTD_sp
# Out:
#    index Ticker Acquisition Date  Quantity  Unit Cost  Cost Basis  \
# 0      0   AAPL       2013-02-07       125      65.40     8175.00
# 6      6     FB       2013-12-13       150      53.32     7998.00
# 1      1    JNJ       2014-02-27       100      81.90     8190.00
# 2      2    MCD       2013-06-04       100      84.99     8499.00
# 3      3   MTCH       2015-12-14       600      13.63     8178.00
# 4      4   NFLX       2016-01-14        75     108.71     8153.25
# 7      7   TWTR       2015-01-05       225      36.38     8185.50
# 5      5    WMT       2013-08-14       125      68.30     8537.50
#
#   Start of Year Latest Date  Ticker Adj Close  ticker return     ...      \
# 0    2017-12-29  2018-03-08            174.29       1.664985     ...
# 6    2017-12-29  2018-03-08            182.34       2.419730     ...
# 1    2017-12-29  2018-03-08            128.54       0.569475     ...
# 2    2017-12-29  2018-03-08            150.62       0.772208     ...
# 3    2017-12-29  2018-03-08             42.22       2.097579     ...
# 4    2017-12-29  2018-03-08            317.00       1.916015     ...
# 7    2017-12-29  2018-03-08             34.85      -0.042056     ...
# 5    2017-12-29  2018-03-08             85.93       0.258126     ...
#
#    Abs. Return Compare  Ticker Share Value  SP 500 Value  Abs Value Compare  \
# 0             0.850364            21786.25  14834.522390        6951.727610
# 6             1.876926            27351.00  12339.342800       15011.657200
# 1             0.092376            12854.00  12097.441231         756.558769
# 2             0.093280            15062.00  14269.211361         792.788639
# 3             1.742954            25332.00  11078.121339       14253.878661
# 4             1.490834            23775.00  11619.857612       12155.142388
# 7            -0.397593             7841.25  11095.744259       -3254.494259
# 5            -0.366999            10741.25  13874.507607       -3133.257607
#
#    Stock Gain / (Loss)  SP 500 Gain / (Loss)  Ticker Start Year Close  \
# 0             13611.25           6659.522390                   166.01
# 6             19353.00           4341.342800                   176.46
# 1              4664.00           3907.441231                   135.13
# 2              6563.00           5770.211361                   166.81
# 3             17154.00           2900.121339                    29.80
# 4             15621.75           3466.607612                   191.96
# 7              -344.25           2910.244259                    24.01
# 5              2203.75           5337.007607                    95.94
#
#    SP Start Year Close  Share YTD  SP 500 YTD
# 0              2673.61   0.049877    0.024446
# 6              2673.61   0.033322    0.024446
# 1              2673.61  -0.048768    0.024446
# 2              2673.61  -0.097057    0.024446
# 3              2673.61   0.416779    0.024446
# 4              2673.61   0.651386    0.024446
# 7              2673.61   0.451479    0.024446
# 5              2673.61  -0.104336    0.024446
#
# [8 rows x 24 columns]

# %%
# Cumulative sum of original investment
merged_portfolio_sp_latest_YTD_sp['Cum Invst'] = merged_portfolio_sp_latest_YTD_sp['Cost Basis'].cumsum()

# %%
merged_portfolio_sp_latest_YTD_sp
# Out:
#    index Ticker Acquisition Date  Quantity  Unit Cost  Cost Basis  \
# 0      0   AAPL       2013-02-07       125      65.40     8175.00
# 6      6     FB       2013-12-13       150      53.32     7998.00
# 1      1    JNJ       2014-02-27       100      81.90     8190.00
# 2      2    MCD       2013-06-04       100      84.99     8499.00
# 3      3   MTCH       2015-12-14       600      13.63     8178.00
# 4      4   NFLX       2016-01-14        75     108.71     8153.25
# 7      7   TWTR       2015-01-05       225      36.38     8185.50
# 5      5    WMT       2013-08-14       125      68.30     8537.50
#
#   Start of Year Latest Date  Ticker Adj Close  ticker return    ...      \
# 0    2017-12-29  2018-03-08            174.29       1.664985    ...
# 6    2017-12-29  2018-03-08            182.34       2.419730    ...
# 1    2017-12-29  2018-03-08            128.54       0.569475    ...
# 2    2017-12-29  2018-03-08            150.62       0.772208    ...
# 3    2017-12-29  2018-03-08             42.22       2.097579    ...
# 4    2017-12-29  2018-03-08            317.00       1.916015    ...
# 7    2017-12-29  2018-03-08             34.85      -0.042056    ...
# 5    2017-12-29  2018-03-08             85.93       0.258126    ...
#
#    Ticker Share Value  SP 500 Value  Abs Value Compare  Stock Gain / (Loss)  \
# 0            21786.25  14834.522390        6951.727610             13611.25
# 6            27351.00  12339.342800       15011.657200             19353.00
# 1            12854.00  12097.441231         756.558769              4664.00
# 2            15062.00  14269.211361         792.788639              6563.00
# 3            25332.00  11078.121339       14253.878661             17154.00
# 4            23775.00  11619.857612       12155.142388             15621.75
# 7             7841.25  11095.744259       -3254.494259              -344.25
# 5            10741.25  13874.507607       -3133.257607              2203.75
#
#    SP 500 Gain / (Loss)  Ticker Start Year Close  SP Start Year Close  \
# 0           6659.522390                   166.01              2673.61
# 6           4341.342800                   176.46              2673.61
# 1           3907.441231                   135.13              2673.61
# 2           5770.211361                   166.81              2673.61
# 3           2900.121339                    29.80              2673.61
# 4           3466.607612                   191.96              2673.61
# 7           2910.244259                    24.01              2673.61
# 5           5337.007607                    95.94              2673.61
#
#    Share YTD  SP 500 YTD  Cum Invst
# 0   0.049877    0.024446    8175.00
# 6   0.033322    0.024446   16173.00
# 1  -0.048768    0.024446   24363.00
# 2  -0.097057    0.024446   32862.00
# 3   0.416779    0.024446   41040.00
# 4   0.651386    0.024446   49193.25
# 7   0.451479    0.024446   57378.75
# 5  -0.104336    0.024446   65916.25
#
# [8 rows x 25 columns]

# %%
# Cumulative sum of Ticker Share Value (latest FMV based on initial quantity purchased).
merged_portfolio_sp_latest_YTD_sp['Cum Ticker Returns'] = merged_portfolio_sp_latest_YTD_sp['Ticker Share Value'].cumsum()

# %%
# Cumulative sum of SP Share Value (latest FMV driven off of initial SP equiv purchase).
merged_portfolio_sp_latest_YTD_sp['Cum SP Returns'] = merged_portfolio_sp_latest_YTD_sp['SP 500 Value'].cumsum()

# %%
# Cumulative CoC multiple return for stock investments
merged_portfolio_sp_latest_YTD_sp['Cum Ticker ROI Mult'] = merged_portfolio_sp_latest_YTD_sp['Cum Ticker Returns'] / merged_portfolio_sp_latest_YTD_sp['Cum Invst']

# %%
merged_portfolio_sp_latest_YTD_sp
# Out:
#    index Ticker Acquisition Date  Quantity  Unit Cost  Cost Basis  \
# 0      0   AAPL       2013-02-07       125      65.40     8175.00
# 6      6     FB       2013-12-13       150      53.32     7998.00
# 1      1    JNJ       2014-02-27       100      81.90     8190.00
# 2      2    MCD       2013-06-04       100      84.99     8499.00
# 3      3   MTCH       2015-12-14       600      13.63     8178.00
# 4      4   NFLX       2016-01-14        75     108.71     8153.25
# 7      7   TWTR       2015-01-05       225      36.38     8185.50
# 5      5    WMT       2013-08-14       125      68.30     8537.50
#
#   Start of Year Latest Date  Ticker Adj Close  ticker return  \
# 0    2017-12-29  2018-03-08            174.29       1.664985
# 6    2017-12-29  2018-03-08            182.34       2.419730
# 1    2017-12-29  2018-03-08            128.54       0.569475
# 2    2017-12-29  2018-03-08            150.62       0.772208
# 3    2017-12-29  2018-03-08             42.22       2.097579
# 4    2017-12-29  2018-03-08            317.00       1.916015
# 7    2017-12-29  2018-03-08             34.85      -0.042056
# 5    2017-12-29  2018-03-08             85.93       0.258126
#
#           ...           Stock Gain / (Loss)  SP 500 Gain / (Loss)  \
# 0         ...                      13611.25           6659.522390
# 6         ...                      19353.00           4341.342800
# 1         ...                       4664.00           3907.441231
# 2         ...                       6563.00           5770.211361
# 3         ...                      17154.00           2900.121339
# 4         ...                      15621.75           3466.607612
# 7         ...                       -344.25           2910.244259
# 5         ...                       2203.75           5337.007607
#
#    Ticker Start Year Close  SP Start Year Close  Share YTD  SP 500 YTD  \
# 0                   166.01              2673.61   0.049877    0.024446
# 6                   176.46              2673.61   0.033322    0.024446
# 1                   135.13              2673.61  -0.048768    0.024446
# 2                   166.81              2673.61  -0.097057    0.024446
# 3                    29.80              2673.61   0.416779    0.024446
# 4                   191.96              2673.61   0.651386    0.024446
# 7                    24.01              2673.61   0.451479    0.024446
# 5                    95.94              2673.61  -0.104336    0.024446
#
#    Cum Invst  Cum Ticker Returns  Cum SP Returns  Cum Ticker ROI Mult
# 0    8175.00            21786.25    14834.522390             2.664985
# 6   16173.00            49137.25    27173.865190             3.038227
# 1   24363.00            61991.25    39271.306421             2.544483
# 2   32862.00            77053.25    53540.517782             2.344752
# 3   41040.00           102385.25    64618.639121             2.494767
# 4   49193.25           126160.25    76238.496732             2.564585
# 7   57378.75           134001.50    87334.240992             2.335385
# 5   65916.25           144742.75   101208.748598             2.195858
#
# [8 rows x 28 columns]

# %%
portfolio_df.reset_index(inplace=True)

portfolio_df.head()
# Out:
#   Ticker Acquisition Date  Quantity  Unit Cost  Cost Basis Start of Year
# 0   AAPL       2013-02-07       125      65.40     8175.00    2017-12-29
# 1    JNJ       2014-02-27       100      81.90     8190.00    2017-12-29
# 2    MCD       2013-06-04       100      84.99     8499.00    2017-12-29
# 3   MTCH       2015-12-14       600      13.63     8178.00    2017-12-29
# 4   NFLX       2016-01-14        75     108.71     8153.25    2017-12-29

# %%
adj_close.head()
# Out:
#   Ticker       Date  Adj Close
# 0   AAPL 2012-12-31      53.97
# 1   AAPL 2013-01-02      55.68
# 2   AAPL 2013-01-03      54.98
# 3   AAPL 2013-01-04      53.45
# 4   AAPL 2013-01-07      53.14

# %%
adj_close_acq_date = pd.merge(adj_close, portfolio_df, on='Ticker')

# %%
del adj_close_acq_date['Quantity']
del adj_close_acq_date['Unit Cost']
del adj_close_acq_date['Cost Basis']
del adj_close_acq_date['Start of Year']

# %%
del adj_close_acq_date['Acquisition Date']

# %%
adj_close_acq_date = pd.merge(adj_close, portfolio_df[['Ticker', 'Acquisition Date']], on='Ticker')

# %%
adj_close_acq_date
# Out:
#      Ticker       Date  Adj Close Acquisition Date
# 0      AAPL 2012-12-31      53.97       2013-02-07
# 1      AAPL 2013-01-02      55.68       2013-02-07
# 2      AAPL 2013-01-03      54.98       2013-02-07
# 3      AAPL 2013-01-04      53.45       2013-02-07
# 4      AAPL 2013-01-07      53.14       2013-02-07
# 5      AAPL 2013-01-08      53.28       2013-02-07
# 6      AAPL 2013-01-09      52.45       2013-02-07
# 7      AAPL 2013-01-10      53.10       2013-02-07
# 8      AAPL 2013-01-11      52.77       2013-02-07
# 9      AAPL 2013-01-14      50.89       2013-02-07
# 10     AAPL 2013-01-15      49.28       2013-02-07
# 11     AAPL 2013-01-16      51.33       2013-02-07
# 12     AAPL 2013-01-17      50.98       2013-02-07
# 13     AAPL 2013-01-18      50.71       2013-02-07
# 14     AAPL 2013-01-22      51.20       2013-02-07
# 15     AAPL 2013-01-23      52.13       2013-02-07
# 16     AAPL 2013-01-24      45.69       2013-02-07
# 17     AAPL 2013-01-25      44.61       2013-02-07
# 18     AAPL 2013-01-28      45.62       2013-02-07
# 19     AAPL 2013-01-29      46.48       2013-02-07
# 20     AAPL 2013-01-30      46.33       2013-02-07
# 21     AAPL 2013-01-31      46.20       2013-02-07
# 22     AAPL 2013-02-01      46.01       2013-02-07
# 23     AAPL 2013-02-04      44.86       2013-02-07
# 24     AAPL 2013-02-05      46.44       2013-02-07
# 25     AAPL 2013-02-06      46.39       2013-02-07
# 26     AAPL 2013-02-07      49.50       2013-02-07
# 27     AAPL 2013-02-08      50.21       2013-02-07
# 28     AAPL 2013-02-11      50.73       2013-02-07
# 29     AAPL 2013-02-12      49.46       2013-02-07
# ...     ...        ...        ...              ...
# 9474   TWTR 2018-01-25      22.16       2015-01-05
# 9475   TWTR 2018-01-26      24.27       2015-01-05
# 9476   TWTR 2018-01-29      25.18       2015-01-05
# 9477   TWTR 2018-01-30      25.62       2015-01-05
# 9478   TWTR 2018-01-31      25.81       2015-01-05
# 9479   TWTR 2018-02-01      27.14       2015-01-05
# 9480   TWTR 2018-02-02      25.92       2015-01-05
# 9481   TWTR 2018-02-05      25.13       2015-01-05
# 9482   TWTR 2018-02-06      25.24       2015-01-05
# 9483   TWTR 2018-02-07      26.91       2015-01-05
# 9484   TWTR 2018-02-08      30.18       2015-01-05
# 9485   TWTR 2018-02-09      31.51       2015-01-05
# 9486   TWTR 2018-02-12      30.95       2015-01-05
# 9487   TWTR 2018-02-13      33.44       2015-01-05
# 9488   TWTR 2018-02-14      33.75       2015-01-05
# 9489   TWTR 2018-02-15      33.61       2015-01-05
# 9490   TWTR 2018-02-16      33.06       2015-01-05
# 9491   TWTR 2018-02-20      32.84       2015-01-05
# 9492   TWTR 2018-02-21      33.38       2015-01-05
# 9493   TWTR 2018-02-22      32.11       2015-01-05
# 9494   TWTR 2018-02-23      32.66       2015-01-05
# 9495   TWTR 2018-02-26      32.16       2015-01-05
# 9496   TWTR 2018-02-27      31.32       2015-01-05
# 9497   TWTR 2018-02-28      31.86       2015-01-05
# 9498   TWTR 2018-03-01      32.24       2015-01-05
# 9499   TWTR 2018-03-02      33.00       2015-01-05
# 9500   TWTR 2018-03-05      34.58       2015-01-05
# 9501   TWTR 2018-03-06      34.43       2015-01-05
# 9502   TWTR 2018-03-07      35.76       2015-01-05
# 9503   TWTR 2018-03-08      34.85       2015-01-05
#
# [9504 rows x 4 columns]

# %%
adj_close_acq_date.sort_values(by=['Ticker', 'Acquisition Date', 'Date'], ascending=[True, True, True], inplace=True)

# %%
adj_close_acq_date['Date Delta'] = adj_close_acq_date['Date'] - adj_close_acq_date['Acquisition Date']

# %%
adj_close_acq_date
# Out:
#      Ticker       Date  Adj Close Acquisition Date Date Delta
# 0      AAPL 2012-12-31      53.97       2013-02-07   -38 days
# 1      AAPL 2013-01-02      55.68       2013-02-07   -36 days
# 2      AAPL 2013-01-03      54.98       2013-02-07   -35 days
# 3      AAPL 2013-01-04      53.45       2013-02-07   -34 days
# 4      AAPL 2013-01-07      53.14       2013-02-07   -31 days
# 5      AAPL 2013-01-08      53.28       2013-02-07   -30 days
# 6      AAPL 2013-01-09      52.45       2013-02-07   -29 days
# 7      AAPL 2013-01-10      53.10       2013-02-07   -28 days
# 8      AAPL 2013-01-11      52.77       2013-02-07   -27 days
# 9      AAPL 2013-01-14      50.89       2013-02-07   -24 days
# 10     AAPL 2013-01-15      49.28       2013-02-07   -23 days
# 11     AAPL 2013-01-16      51.33       2013-02-07   -22 days
# 12     AAPL 2013-01-17      50.98       2013-02-07   -21 days
# 13     AAPL 2013-01-18      50.71       2013-02-07   -20 days
# 14     AAPL 2013-01-22      51.20       2013-02-07   -16 days
# 15     AAPL 2013-01-23      52.13       2013-02-07   -15 days
# 16     AAPL 2013-01-24      45.69       2013-02-07   -14 days
# 17     AAPL 2013-01-25      44.61       2013-02-07   -13 days
# 18     AAPL 2013-01-28      45.62       2013-02-07   -10 days
# 19     AAPL 2013-01-29      46.48       2013-02-07    -9 days
# 20     AAPL 2013-01-30      46.33       2013-02-07    -8 days
# 21     AAPL 2013-01-31      46.20       2013-02-07    -7 days
# 22     AAPL 2013-02-01      46.01       2013-02-07    -6 days
# 23     AAPL 2013-02-04      44.86       2013-02-07    -3 days
# 24     AAPL 2013-02-05      46.44       2013-02-07    -2 days
# 25     AAPL 2013-02-06      46.39       2013-02-07    -1 days
# 26     AAPL 2013-02-07      49.50       2013-02-07     0 days
# 27     AAPL 2013-02-08      50.21       2013-02-07     1 days
# 28     AAPL 2013-02-11      50.73       2013-02-07     4 days
# 29     AAPL 2013-02-12      49.46       2013-02-07     5 days
# ...     ...        ...        ...              ...        ...
# 7078    WMT 2018-01-25     103.57       2013-08-14  1625 days
# 7079    WMT 2018-01-26     105.31       2013-08-14  1626 days
# 7080    WMT 2018-01-29     106.44       2013-08-14  1629 days
# 7081    WMT 2018-01-30     104.67       2013-08-14  1630 days
# 7082    WMT 2018-01-31     103.57       2013-08-14  1631 days
# 7083    WMT 2018-02-01     102.52       2013-08-14  1632 days
# 7084    WMT 2018-02-02     101.51       2013-08-14  1633 days
# 7085    WMT 2018-02-05      97.25       2013-08-14  1636 days
# 7086    WMT 2018-02-06      98.03       2013-08-14  1637 days
# 7087    WMT 2018-02-07      99.93       2013-08-14  1638 days
# 7088    WMT 2018-02-08      97.18       2013-08-14  1639 days
# 7089    WMT 2018-02-09      96.55       2013-08-14  1640 days
# 7090    WMT 2018-02-12      96.72       2013-08-14  1643 days
# 7091    WMT 2018-02-13      98.11       2013-08-14  1644 days
# 7092    WMT 2018-02-14      98.81       2013-08-14  1645 days
# 7093    WMT 2018-02-15     100.30       2013-08-14  1646 days
# 7094    WMT 2018-02-16     101.80       2013-08-14  1647 days
# 7095    WMT 2018-02-20      91.44       2013-08-14  1651 days
# 7096    WMT 2018-02-21      88.92       2013-08-14  1652 days
# 7097    WMT 2018-02-22      90.13       2013-08-14  1653 days
# 7098    WMT 2018-02-23      90.25       2013-08-14  1654 days
# 7099    WMT 2018-02-26      90.47       2013-08-14  1657 days
# 7100    WMT 2018-02-27      88.92       2013-08-14  1658 days
# 7101    WMT 2018-02-28      87.45       2013-08-14  1659 days
# 7102    WMT 2018-03-01      86.55       2013-08-14  1660 days
# 7103    WMT 2018-03-02      86.25       2013-08-14  1661 days
# 7104    WMT 2018-03-05      87.42       2013-08-14  1664 days
# 7105    WMT 2018-03-06      86.53       2013-08-14  1665 days
# 7106    WMT 2018-03-07      85.25       2013-08-14  1666 days
# 7107    WMT 2018-03-08      85.93       2013-08-14  1667 days
#
# [9504 rows x 5 columns]

# %%
adj_close_acq_date['Date Delta'] = adj_close_acq_date[['Date Delta']].apply(pd.to_numeric)

# %%
adj_close_acq_date
# Out:
#      Ticker       Date  Adj Close Acquisition Date          Date Delta
# 0      AAPL 2012-12-31      53.97       2013-02-07   -3283200000000000
# 1      AAPL 2013-01-02      55.68       2013-02-07   -3110400000000000
# 2      AAPL 2013-01-03      54.98       2013-02-07   -3024000000000000
# 3      AAPL 2013-01-04      53.45       2013-02-07   -2937600000000000
# 4      AAPL 2013-01-07      53.14       2013-02-07   -2678400000000000
# 5      AAPL 2013-01-08      53.28       2013-02-07   -2592000000000000
# 6      AAPL 2013-01-09      52.45       2013-02-07   -2505600000000000
# 7      AAPL 2013-01-10      53.10       2013-02-07   -2419200000000000
# 8      AAPL 2013-01-11      52.77       2013-02-07   -2332800000000000
# 9      AAPL 2013-01-14      50.89       2013-02-07   -2073600000000000
# 10     AAPL 2013-01-15      49.28       2013-02-07   -1987200000000000
# 11     AAPL 2013-01-16      51.33       2013-02-07   -1900800000000000
# 12     AAPL 2013-01-17      50.98       2013-02-07   -1814400000000000
# 13     AAPL 2013-01-18      50.71       2013-02-07   -1728000000000000
# 14     AAPL 2013-01-22      51.20       2013-02-07   -1382400000000000
# 15     AAPL 2013-01-23      52.13       2013-02-07   -1296000000000000
# 16     AAPL 2013-01-24      45.69       2013-02-07   -1209600000000000
# 17     AAPL 2013-01-25      44.61       2013-02-07   -1123200000000000
# 18     AAPL 2013-01-28      45.62       2013-02-07    -864000000000000
# 19     AAPL 2013-01-29      46.48       2013-02-07    -777600000000000
# 20     AAPL 2013-01-30      46.33       2013-02-07    -691200000000000
# 21     AAPL 2013-01-31      46.20       2013-02-07    -604800000000000
# 22     AAPL 2013-02-01      46.01       2013-02-07    -518400000000000
# 23     AAPL 2013-02-04      44.86       2013-02-07    -259200000000000
# 24     AAPL 2013-02-05      46.44       2013-02-07    -172800000000000
# 25     AAPL 2013-02-06      46.39       2013-02-07     -86400000000000
# 26     AAPL 2013-02-07      49.50       2013-02-07                   0
# 27     AAPL 2013-02-08      50.21       2013-02-07      86400000000000
# 28     AAPL 2013-02-11      50.73       2013-02-07     345600000000000
# 29     AAPL 2013-02-12      49.46       2013-02-07     432000000000000
# ...     ...        ...        ...              ...                 ...
# 7078    WMT 2018-01-25     103.57       2013-08-14  140400000000000000
# 7079    WMT 2018-01-26     105.31       2013-08-14  140486400000000000
# 7080    WMT 2018-01-29     106.44       2013-08-14  140745600000000000
# 7081    WMT 2018-01-30     104.67       2013-08-14  140832000000000000
# 7082    WMT 2018-01-31     103.57       2013-08-14  140918400000000000
# 7083    WMT 2018-02-01     102.52       2013-08-14  141004800000000000
# 7084    WMT 2018-02-02     101.51       2013-08-14  141091200000000000
# 7085    WMT 2018-02-05      97.25       2013-08-14  141350400000000000
# 7086    WMT 2018-02-06      98.03       2013-08-14  141436800000000000
# 7087    WMT 2018-02-07      99.93       2013-08-14  141523200000000000
# 7088    WMT 2018-02-08      97.18       2013-08-14  141609600000000000
# 7089    WMT 2018-02-09      96.55       2013-08-14  141696000000000000
# 7090    WMT 2018-02-12      96.72       2013-08-14  141955200000000000
# 7091    WMT 2018-02-13      98.11       2013-08-14  142041600000000000
# 7092    WMT 2018-02-14      98.81       2013-08-14  142128000000000000
# 7093    WMT 2018-02-15     100.30       2013-08-14  142214400000000000
# 7094    WMT 2018-02-16     101.80       2013-08-14  142300800000000000
# 7095    WMT 2018-02-20      91.44       2013-08-14  142646400000000000
# 7096    WMT 2018-02-21      88.92       2013-08-14  142732800000000000
# 7097    WMT 2018-02-22      90.13       2013-08-14  142819200000000000
# 7098    WMT 2018-02-23      90.25       2013-08-14  142905600000000000
# 7099    WMT 2018-02-26      90.47       2013-08-14  143164800000000000
# 7100    WMT 2018-02-27      88.92       2013-08-14  143251200000000000
# 7101    WMT 2018-02-28      87.45       2013-08-14  143337600000000000
# 7102    WMT 2018-03-01      86.55       2013-08-14  143424000000000000
# 7103    WMT 2018-03-02      86.25       2013-08-14  143510400000000000
# 7104    WMT 2018-03-05      87.42       2013-08-14  143769600000000000
# 7105    WMT 2018-03-06      86.53       2013-08-14  143856000000000000
# 7106    WMT 2018-03-07      85.25       2013-08-14  143942400000000000
# 7107    WMT 2018-03-08      85.93       2013-08-14  144028800000000000
#
# [9504 rows x 5 columns]

# %%
adj_close_acq_date_modified = adj_close_acq_date[adj_close_acq_date['Date Delta']>=0]

# %%
adj_close_acq_date_modified
# Out:
#      Ticker       Date  Adj Close Acquisition Date          Date Delta
# 26     AAPL 2013-02-07      49.50       2013-02-07                   0
# 27     AAPL 2013-02-08      50.21       2013-02-07      86400000000000
# 28     AAPL 2013-02-11      50.73       2013-02-07     345600000000000
# 29     AAPL 2013-02-12      49.46       2013-02-07     432000000000000
# 30     AAPL 2013-02-13      49.37       2013-02-07     518400000000000
# 31     AAPL 2013-02-14      49.32       2013-02-07     604800000000000
# 32     AAPL 2013-02-15      48.64       2013-02-07     691200000000000
# 33     AAPL 2013-02-19      48.63       2013-02-07    1036800000000000
# 34     AAPL 2013-02-20      47.45       2013-02-07    1123200000000000
# 35     AAPL 2013-02-21      47.15       2013-02-07    1209600000000000
# 36     AAPL 2013-02-22      47.66       2013-02-07    1296000000000000
# 37     AAPL 2013-02-25      46.81       2013-02-07    1555200000000000
# 38     AAPL 2013-02-26      47.46       2013-02-07    1641600000000000
# 39     AAPL 2013-02-27      47.00       2013-02-07    1728000000000000
# 40     AAPL 2013-02-28      46.66       2013-02-07    1814400000000000
# 41     AAPL 2013-03-01      45.51       2013-02-07    1900800000000000
# 42     AAPL 2013-03-04      44.40       2013-02-07    2160000000000000
# 43     AAPL 2013-03-05      45.58       2013-02-07    2246400000000000
# 44     AAPL 2013-03-06      45.00       2013-02-07    2332800000000000
# 45     AAPL 2013-03-07      45.52       2013-02-07    2419200000000000
# 46     AAPL 2013-03-08      45.64       2013-02-07    2505600000000000
# 47     AAPL 2013-03-11      46.29       2013-02-07    2764800000000000
# 48     AAPL 2013-03-12      45.29       2013-02-07    2851200000000000
# 49     AAPL 2013-03-13      45.28       2013-02-07    2937600000000000
# 50     AAPL 2013-03-14      45.72       2013-02-07    3024000000000000
# 51     AAPL 2013-03-15      46.90       2013-02-07    3110400000000000
# 52     AAPL 2013-03-18      48.17       2013-02-07    3369600000000000
# 53     AAPL 2013-03-19      48.04       2013-02-07    3456000000000000
# 54     AAPL 2013-03-20      47.79       2013-02-07    3542400000000000
# 55     AAPL 2013-03-21      47.86       2013-02-07    3628800000000000
# ...     ...        ...        ...              ...                 ...
# 7078    WMT 2018-01-25     103.57       2013-08-14  140400000000000000
# 7079    WMT 2018-01-26     105.31       2013-08-14  140486400000000000
# 7080    WMT 2018-01-29     106.44       2013-08-14  140745600000000000
# 7081    WMT 2018-01-30     104.67       2013-08-14  140832000000000000
# 7082    WMT 2018-01-31     103.57       2013-08-14  140918400000000000
# 7083    WMT 2018-02-01     102.52       2013-08-14  141004800000000000
# 7084    WMT 2018-02-02     101.51       2013-08-14  141091200000000000
# 7085    WMT 2018-02-05      97.25       2013-08-14  141350400000000000
# 7086    WMT 2018-02-06      98.03       2013-08-14  141436800000000000
# 7087    WMT 2018-02-07      99.93       2013-08-14  141523200000000000
# 7088    WMT 2018-02-08      97.18       2013-08-14  141609600000000000
# 7089    WMT 2018-02-09      96.55       2013-08-14  141696000000000000
# 7090    WMT 2018-02-12      96.72       2013-08-14  141955200000000000
# 7091    WMT 2018-02-13      98.11       2013-08-14  142041600000000000
# 7092    WMT 2018-02-14      98.81       2013-08-14  142128000000000000
# 7093    WMT 2018-02-15     100.30       2013-08-14  142214400000000000
# 7094    WMT 2018-02-16     101.80       2013-08-14  142300800000000000
# 7095    WMT 2018-02-20      91.44       2013-08-14  142646400000000000
# 7096    WMT 2018-02-21      88.92       2013-08-14  142732800000000000
# 7097    WMT 2018-02-22      90.13       2013-08-14  142819200000000000
# 7098    WMT 2018-02-23      90.25       2013-08-14  142905600000000000
# 7099    WMT 2018-02-26      90.47       2013-08-14  143164800000000000
# 7100    WMT 2018-02-27      88.92       2013-08-14  143251200000000000
# 7101    WMT 2018-02-28      87.45       2013-08-14  143337600000000000
# 7102    WMT 2018-03-01      86.55       2013-08-14  143424000000000000
# 7103    WMT 2018-03-02      86.25       2013-08-14  143510400000000000
# 7104    WMT 2018-03-05      87.42       2013-08-14  143769600000000000
# 7105    WMT 2018-03-06      86.53       2013-08-14  143856000000000000
# 7106    WMT 2018-03-07      85.25       2013-08-14  143942400000000000
# 7107    WMT 2018-03-08      85.93       2013-08-14  144028800000000000
#
# [7613 rows x 5 columns]

# %%
adj_close_pivot = adj_close_acq_date_modified.pivot_table(index=['Ticker', 'Acquisition Date'], values='Adj Close', aggfunc=np.max)

# %%
adj_close_pivot
# Out:
#                          Adj Close
# Ticker Acquisition Date
# AAPL   2013-02-07           176.29
# FB     2013-12-13           193.09
# JNJ    2014-02-27           143.28
# MCD    2013-06-04           172.85
# MTCH   2015-12-14            42.22
# NFLX   2016-01-14           325.22
# TWTR   2015-01-05            52.87
# WMT    2013-08-14           106.44

# %%
adj_close_pivot.reset_index(inplace=True)

# %%
adj_close
# Out:
#      Ticker       Date  Adj Close
# 0      AAPL 2012-12-31      53.97
# 1      AAPL 2013-01-02      55.68
# 2      AAPL 2013-01-03      54.98
# 3      AAPL 2013-01-04      53.45
# 4      AAPL 2013-01-07      53.14
# 5      AAPL 2013-01-08      53.28
# 6      AAPL 2013-01-09      52.45
# 7      AAPL 2013-01-10      53.10
# 8      AAPL 2013-01-11      52.77
# 9      AAPL 2013-01-14      50.89
# 10     AAPL 2013-01-15      49.28
# 11     AAPL 2013-01-16      51.33
# 12     AAPL 2013-01-17      50.98
# 13     AAPL 2013-01-18      50.71
# 14     AAPL 2013-01-22      51.20
# 15     AAPL 2013-01-23      52.13
# 16     AAPL 2013-01-24      45.69
# 17     AAPL 2013-01-25      44.61
# 18     AAPL 2013-01-28      45.62
# 19     AAPL 2013-01-29      46.48
# 20     AAPL 2013-01-30      46.33
# 21     AAPL 2013-01-31      46.20
# 22     AAPL 2013-02-01      46.01
# 23     AAPL 2013-02-04      44.86
# 24     AAPL 2013-02-05      46.44
# 25     AAPL 2013-02-06      46.39
# 26     AAPL 2013-02-07      49.50
# 27     AAPL 2013-02-08      50.21
# 28     AAPL 2013-02-11      50.73
# 29     AAPL 2013-02-12      49.46
# ...     ...        ...        ...
# 9474   TWTR 2018-01-25      22.16
# 9475   TWTR 2018-01-26      24.27
# 9476   TWTR 2018-01-29      25.18
# 9477   TWTR 2018-01-30      25.62
# 9478   TWTR 2018-01-31      25.81
# 9479   TWTR 2018-02-01      27.14
# 9480   TWTR 2018-02-02      25.92
# 9481   TWTR 2018-02-05      25.13
# 9482   TWTR 2018-02-06      25.24
# 9483   TWTR 2018-02-07      26.91
# 9484   TWTR 2018-02-08      30.18
# 9485   TWTR 2018-02-09      31.51
# 9486   TWTR 2018-02-12      30.95
# 9487   TWTR 2018-02-13      33.44
# 9488   TWTR 2018-02-14      33.75
# 9489   TWTR 2018-02-15      33.61
# 9490   TWTR 2018-02-16      33.06
# 9491   TWTR 2018-02-20      32.84
# 9492   TWTR 2018-02-21      33.38
# 9493   TWTR 2018-02-22      32.11
# 9494   TWTR 2018-02-23      32.66
# 9495   TWTR 2018-02-26      32.16
# 9496   TWTR 2018-02-27      31.32
# 9497   TWTR 2018-02-28      31.86
# 9498   TWTR 2018-03-01      32.24
# 9499   TWTR 2018-03-02      33.00
# 9500   TWTR 2018-03-05      34.58
# 9501   TWTR 2018-03-06      34.43
# 9502   TWTR 2018-03-07      35.76
# 9503   TWTR 2018-03-08      34.85
#
# [9504 rows x 3 columns]

# %%
adj_close_pivot_merged = pd.merge(adj_close_pivot, adj_close
                                             , on=['Ticker', 'Adj Close'])

# %%
adj_close_pivot_merged
# Out:
#   Ticker Acquisition Date  Adj Close       Date
# 0   AAPL       2013-02-07     176.29 2018-02-26
# 1     FB       2013-12-13     193.09 2018-02-01
# 2    JNJ       2014-02-27     143.28 2018-01-22
# 3    MCD       2013-06-04     172.85 2018-01-26
# 4   MTCH       2015-12-14      42.22 2018-03-08
# 5   NFLX       2016-01-14     325.22 2018-03-06
# 6   TWTR       2015-01-05      52.87 2015-04-07
# 7    WMT       2013-08-14     106.44 2018-01-29

# %%
merged_portfolio_sp_latest_YTD_sp_closing_high = pd.merge(merged_portfolio_sp_latest_YTD_sp, adj_close_pivot_merged
                                             , on=['Ticker', 'Acquisition Date'])

# %%
merged_portfolio_sp_latest_YTD_sp_closing_high
# Out:
#    index Ticker Acquisition Date  Quantity  Unit Cost  Cost Basis  \
# 0      0   AAPL       2013-02-07       125      65.40     8175.00
# 1      6     FB       2013-12-13       150      53.32     7998.00
# 2      1    JNJ       2014-02-27       100      81.90     8190.00
# 3      2    MCD       2013-06-04       100      84.99     8499.00
# 4      3   MTCH       2015-12-14       600      13.63     8178.00
# 5      4   NFLX       2016-01-14        75     108.71     8153.25
# 6      7   TWTR       2015-01-05       225      36.38     8185.50
# 7      5    WMT       2013-08-14       125      68.30     8537.50
#
#   Start of Year Latest Date  Ticker Adj Close  ticker return    ...      \
# 0    2017-12-29  2018-03-08            174.29       1.664985    ...
# 1    2017-12-29  2018-03-08            182.34       2.419730    ...
# 2    2017-12-29  2018-03-08            128.54       0.569475    ...
# 3    2017-12-29  2018-03-08            150.62       0.772208    ...
# 4    2017-12-29  2018-03-08             42.22       2.097579    ...
# 5    2017-12-29  2018-03-08            317.00       1.916015    ...
# 6    2017-12-29  2018-03-08             34.85      -0.042056    ...
# 7    2017-12-29  2018-03-08             85.93       0.258126    ...
#
#    Ticker Start Year Close  SP Start Year Close  Share YTD  SP 500 YTD  \
# 0                   166.01              2673.61   0.049877    0.024446
# 1                   176.46              2673.61   0.033322    0.024446
# 2                   135.13              2673.61  -0.048768    0.024446
# 3                   166.81              2673.61  -0.097057    0.024446
# 4                    29.80              2673.61   0.416779    0.024446
# 5                   191.96              2673.61   0.651386    0.024446
# 6                    24.01              2673.61   0.451479    0.024446
# 7                    95.94              2673.61  -0.104336    0.024446
#
#    Cum Invst  Cum Ticker Returns  Cum SP Returns  Cum Ticker ROI Mult  \
# 0    8175.00            21786.25    14834.522390             2.664985
# 1   16173.00            49137.25    27173.865190             3.038227
# 2   24363.00            61991.25    39271.306421             2.544483
# 3   32862.00            77053.25    53540.517782             2.344752
# 4   41040.00           102385.25    64618.639121             2.494767
# 5   49193.25           126160.25    76238.496732             2.564585
# 6   57378.75           134001.50    87334.240992             2.335385
# 7   65916.25           144742.75   101208.748598             2.195858
#
#    Adj Close       Date
# 0     176.29 2018-02-26
# 1     193.09 2018-02-01
# 2     143.28 2018-01-22
# 3     172.85 2018-01-26
# 4      42.22 2018-03-08
# 5     325.22 2018-03-06
# 6      52.87 2015-04-07
# 7     106.44 2018-01-29
#
# [8 rows x 30 columns]

# %%
merged_portfolio_sp_latest_YTD_sp_closing_high.rename(columns={'Adj Close': 'Closing High Adj Close', 'Date': 'Closing High Adj Close Date'}, inplace=True)

# %%
merged_portfolio_sp_latest_YTD_sp_closing_high['Pct off High'] = merged_portfolio_sp_latest_YTD_sp_closing_high['Ticker Adj Close'] / merged_portfolio_sp_latest_YTD_sp_closing_high['Closing High Adj Close'] - 1

# %%
merged_portfolio_sp_latest_YTD_sp_closing_high
# Out:
#    index Ticker Acquisition Date  Quantity  Unit Cost  Cost Basis  \
# 0      0   AAPL       2013-02-07       125      65.40     8175.00
# 1      6     FB       2013-12-13       150      53.32     7998.00
# 2      1    JNJ       2014-02-27       100      81.90     8190.00
# 3      2    MCD       2013-06-04       100      84.99     8499.00
# 4      3   MTCH       2015-12-14       600      13.63     8178.00
# 5      4   NFLX       2016-01-14        75     108.71     8153.25
# 6      7   TWTR       2015-01-05       225      36.38     8185.50
# 7      5    WMT       2013-08-14       125      68.30     8537.50
#
#   Start of Year Latest Date  Ticker Adj Close  ticker return      ...       \
# 0    2017-12-29  2018-03-08            174.29       1.664985      ...
# 1    2017-12-29  2018-03-08            182.34       2.419730      ...
# 2    2017-12-29  2018-03-08            128.54       0.569475      ...
# 3    2017-12-29  2018-03-08            150.62       0.772208      ...
# 4    2017-12-29  2018-03-08             42.22       2.097579      ...
# 5    2017-12-29  2018-03-08            317.00       1.916015      ...
# 6    2017-12-29  2018-03-08             34.85      -0.042056      ...
# 7    2017-12-29  2018-03-08             85.93       0.258126      ...
#
#    SP Start Year Close  Share YTD  SP 500 YTD  Cum Invst  Cum Ticker Returns  \
# 0              2673.61   0.049877    0.024446    8175.00            21786.25
# 1              2673.61   0.033322    0.024446   16173.00            49137.25
# 2              2673.61  -0.048768    0.024446   24363.00            61991.25
# 3              2673.61  -0.097057    0.024446   32862.00            77053.25
# 4              2673.61   0.416779    0.024446   41040.00           102385.25
# 5              2673.61   0.651386    0.024446   49193.25           126160.25
# 6              2673.61   0.451479    0.024446   57378.75           134001.50
# 7              2673.61  -0.104336    0.024446   65916.25           144742.75
#
#    Cum SP Returns  Cum Ticker ROI Mult  Closing High Adj Close  \
# 0    14834.522390             2.664985                  176.29
# 1    27173.865190             3.038227                  193.09
# 2    39271.306421             2.544483                  143.28
# 3    53540.517782             2.344752                  172.85
# 4    64618.639121             2.494767                   42.22
# 5    76238.496732             2.564585                  325.22
# 6    87334.240992             2.335385                   52.87
# 7   101208.748598             2.195858                  106.44
#
#    Closing High Adj Close Date  Pct off High
# 0                   2018-02-26     -0.011345
# 1                   2018-02-01     -0.055674
# 2                   2018-01-22     -0.102875
# 3                   2018-01-26     -0.128609
# 4                   2018-03-08      0.000000
# 5                   2018-03-06     -0.025275
# 6                   2015-04-07     -0.340836
# 7                   2018-01-29     -0.192691
#
# [8 rows x 31 columns]

# %%
merged_portfolio_sp_latest_YTD_sp_closing_high.columns
# Out:
# Index(['index', 'Ticker', 'Acquisition Date', 'Quantity', 'Unit Cost',
#        'Cost Basis', 'Start of Year', 'Latest Date', 'Ticker Adj Close',
#        'ticker return', 'SP 500 Initial Close', 'Equiv SP Shares',
#        'SP 500 Latest Close', 'SP Return', 'Abs. Return Compare',
#        'Ticker Share Value', 'SP 500 Value', 'Abs Value Compare',
#        'Stock Gain / (Loss)', 'SP 500 Gain / (Loss)',
#        'Ticker Start Year Close', 'SP Start Year Close', 'Share YTD',
#        'SP 500 YTD', 'Cum Invst', 'Cum Ticker Returns', 'Cum SP Returns',
#        'Cum Ticker ROI Mult', 'Closing High Adj Close',
#        'Closing High Adj Close Date', 'Pct off High'],
#       dtype='object')

# %%
trace1 = go.Bar(
    x = merged_portfolio_sp_latest_YTD_sp_closing_high['Ticker'],
    y = merged_portfolio_sp_latest_YTD_sp_closing_high['ticker return'],
    name = 'Ticker Total Return')
trace2 = go.Scatter(
    x = merged_portfolio_sp_latest_YTD_sp_closing_high['Ticker'][0:10],
    y = merged_portfolio_sp_latest_YTD_sp_closing_high['SP Return'][0:10],
    name = 'SP500 Total Return')
    
data = [trace1, trace2]
layout = go.Layout(title = 'Total Return vs S&P 500'
    , barmode = 'group'
    , yaxis=dict(title='Returns', tickformat=".2%")
    , xaxis=dict(title='Ticker')
    , legend=dict(x=.8,y=1)
    )
fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="9bfba7e4-edac-4486-b077-a71ce72a23ef" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("9bfba7e4-edac-4486-b077-a71ce72a23ef")) {
#                     Plotly.newPlot(
#                         '9bfba7e4-edac-4486-b077-a71ce72a23ef',
#                         [{"name": "Ticker Total Return", "type": "bar", "uid": "f8815bd0-d475-43b8-bded-35137010197d", "x": ["AAPL", "FB", "JNJ", "MCD", "MTCH", "NFLX", "TWTR", "WMT"], "y": [1.6649847094801218, 2.4197299324831207, 0.5694749694749692, 0.7722084951170727, 2.0975788701393983, 1.9160150860086471, -0.0420560747663552, 0.2581259150805273]}, {"name": "SP500 Total Return", "type": "scatter", "uid": "93d48d29-ffd5-4c31-baf0-c2de24116c0e", "x": ["AAPL", "FB", "JNJ", "MCD", "MTCH", "NFLX", "TWTR", "WMT"], "y": [0.814620475821358, 0.5428035509091318, 0.47709905138894126, 0.6789282693180005, 0.35462476631354023, 0.4251810764683843, 0.35553652911540246, 0.6251253419089942]}],
#                         {"barmode": "group", "legend": {"x": 0.8, "y": 1}, "title": {"text": "Total Return vs S&P 500"}, "xaxis": {"title": {"text": "Ticker"}}, "yaxis": {"tickformat": ".2%", "title": {"text": "Returns"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('9bfba7e4-edac-4486-b077-a71ce72a23ef');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace1 = go.Bar(
    x = merged_portfolio_sp_latest_YTD_sp_closing_high['Ticker'][0:10],
    y = (merged_portfolio_sp_latest_YTD_sp_closing_high['ticker return'] * merged_portfolio_sp_latest_YTD_sp_closing_high['Cost Basis'])[0:10],
    name = 'Ticker Total Return($)')
trace2 = go.Bar(
    x = merged_portfolio_sp_latest_YTD_sp_closing_high['Ticker'][0:10],
    y = (merged_portfolio_sp_latest_YTD_sp_closing_high['SP Return'] * merged_portfolio_sp_latest_YTD_sp_closing_high['Cost Basis'])[0:10],
    name = 'SP500 Total Return($)')
trace3 = go.Scatter(
    x = merged_portfolio_sp_latest_YTD_sp_closing_high['Ticker'][0:10],
    y = merged_portfolio_sp_latest_YTD_sp_closing_high['ticker return'][0:10],
    name = 'Ticker Total Return(%)',
    yaxis = 'y2')

data = [trace1, trace2, trace3]
layout = go.Layout(title = 'Gain/(Loss) Total Return vs S&P 500'
    , barmode = 'group'
    , yaxis=dict(title='Gain/(Loss) ($)')
    , yaxis2=dict(title='Ticker Return', tickformat=".2%", overlaying='y', side='right')
    , xaxis=dict(title='Ticker')
    , legend=dict(x=.8,y=1)
    )
fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="648876de-9fed-4cf4-8ed7-abac19064b15" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("648876de-9fed-4cf4-8ed7-abac19064b15")) {
#                     Plotly.newPlot(
#                         '648876de-9fed-4cf4-8ed7-abac19064b15',
#                         [{"name": "Ticker Total Return($)", "type": "bar", "uid": "b59187cc-5e58-4106-88d6-82d7c745f884", "x": ["AAPL", "FB", "JNJ", "MCD", "MTCH", "NFLX", "TWTR", "WMT"], "y": [13611.249999999996, 19353.0, 4663.999999999998, 6563.000000000001, 17154.0, 15621.75, -344.2500000000005, 2203.750000000002]}, {"name": "SP500 Total Return($)", "type": "bar", "uid": "7fd533db-0663-4deb-94fc-1392d2f727dd", "x": ["AAPL", "FB", "JNJ", "MCD", "MTCH", "NFLX", "TWTR", "WMT"], "y": [6659.5223898396025, 4341.342800171236, 3907.4412308754295, 5770.211360933687, 2900.121338912132, 3466.607611715854, 2910.244259074127, 5337.007606548038]}, {"name": "Ticker Total Return(%)", "type": "scatter", "uid": "03d015ee-95cb-4f78-9a68-129be580e1cc", "x": ["AAPL", "FB", "JNJ", "MCD", "MTCH", "NFLX", "TWTR", "WMT"], "y": [1.6649847094801218, 2.4197299324831207, 0.5694749694749692, 0.7722084951170727, 2.0975788701393983, 1.9160150860086471, -0.0420560747663552, 0.2581259150805273], "yaxis": "y2"}],
#                         {"barmode": "group", "legend": {"x": 0.8, "y": 1}, "title": {"text": "Gain/(Loss) Total Return vs S&P 500"}, "xaxis": {"title": {"text": "Ticker"}}, "yaxis": {"title": {"text": "Gain/(Loss) ($)"}}, "yaxis2": {"overlaying": "y", "side": "right", "tickformat": ".2%", "title": {"text": "Ticker Return"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('648876de-9fed-4cf4-8ed7-abac19064b15');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
merged_portfolio_sp_latest_YTD_sp_closing_high.columns
# Out:
# Index(['index', 'Ticker', 'Acquisition Date', 'Quantity', 'Unit Cost',
#        'Cost Basis', 'Start of Year', 'Latest Date', 'Ticker Adj Close',
#        'ticker return', 'SP 500 Initial Close', 'Equiv SP Shares',
#        'SP 500 Latest Close', 'SP Return', 'Abs. Return Compare',
#        'Ticker Share Value', 'SP 500 Value', 'Abs Value Compare',
#        'Stock Gain / (Loss)', 'SP 500 Gain / (Loss)',
#        'Ticker Start Year Close', 'SP Start Year Close', 'Share YTD',
#        'SP 500 YTD', 'Cum Invst', 'Cum Ticker Returns', 'Cum SP Returns',
#        'Cum Ticker ROI Mult', 'Closing High Adj Close',
#        'Closing High Adj Close Date', 'Pct off High'],
#       dtype='object')

# %%
trace1 = go.Bar(
    x = merged_portfolio_sp_latest_YTD_sp_closing_high['Ticker'][0:10],
    y = merged_portfolio_sp_latest_YTD_sp_closing_high['Cum Invst'][0:10],
    name = 'Cum Invest')
trace2 = go.Bar(
    x = merged_portfolio_sp_latest_YTD_sp_closing_high['Ticker'][0:10],
    y = merged_portfolio_sp_latest_YTD_sp_closing_high['Cum SP Returns'][0:10],
    name = 'Cum SP500 Returns')
trace3 = go.Bar(
    x = merged_portfolio_sp_latest_YTD_sp_closing_high['Ticker'][0:10],
    y = merged_portfolio_sp_latest_YTD_sp_closing_high['Cum Ticker Returns'][0:10],
    name = 'Cum Ticker Returns')
trace4 = go.Scatter(
    x = merged_portfolio_sp_latest_YTD_sp_closing_high['Ticker'][0:10],
    y = merged_portfolio_sp_latest_YTD_sp_closing_high['Cum Ticker ROI Mult'][0:10],
    name = 'Cum Ticker ROI Mult',
    yaxis = 'y2')

data = [trace1, trace2, trace3, trace4]
layout = go.Layout(title = 'Total Cumulative Investments Over Time'
    , barmode = 'group'
    , yaxis=dict(title='Returns')
    , yaxis2=dict(title='Cum ROI Mult', overlaying='y', side='right')
    , xaxis=dict(title='Ticker')
    , legend=dict(x=.8,y=1)
    )
fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="6f8a134d-2344-49bf-876b-6cdd4100bf56" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6f8a134d-2344-49bf-876b-6cdd4100bf56")) {
#                     Plotly.newPlot(
#                         '6f8a134d-2344-49bf-876b-6cdd4100bf56',
#                         [{"name": "Cum Invest", "type": "bar", "uid": "0e93d214-d696-49d9-aa69-447763182ed3", "x": ["AAPL", "FB", "JNJ", "MCD", "MTCH", "NFLX", "TWTR", "WMT"], "y": [8175.000000000001, 16173.0, 24363.0, 32862.0, 41040.0, 49193.25, 57378.75, 65916.25]}, {"name": "Cum SP500 Returns", "type": "bar", "uid": "c61ca2ec-3d03-4955-a45a-362056c0b8d5", "x": ["AAPL", "FB", "JNJ", "MCD", "MTCH", "NFLX", "TWTR", "WMT"], "y": [14834.522389839605, 27173.86519001084, 39271.30642088627, 53540.51778181996, 64618.63912073209, 76238.49673244795, 87334.24099152208, 101208.74859807012]}, {"name": "Cum Ticker Returns", "type": "bar", "uid": "27f623fc-c811-42a7-89a0-ba21b3d24326", "x": ["AAPL", "FB", "JNJ", "MCD", "MTCH", "NFLX", "TWTR", "WMT"], "y": [21786.25, 49137.25, 61991.25, 77053.25, 102385.25, 126160.25, 134001.5, 144742.75]}, {"name": "Cum Ticker ROI Mult", "type": "scatter", "uid": "ffbbb9ff-cbe3-42d5-9ff4-f86884cd520e", "x": ["AAPL", "FB", "JNJ", "MCD", "MTCH", "NFLX", "TWTR", "WMT"], "y": [2.6649847094801222, 3.038227292400915, 2.5444834380002463, 2.3447522974864583, 2.494767300194932, 2.564584572070355, 2.335385486787356, 2.1958583809000056], "yaxis": "y2"}],
#                         {"barmode": "group", "legend": {"x": 0.8, "y": 1}, "title": {"text": "Total Cumulative Investments Over Time"}, "xaxis": {"title": {"text": "Ticker"}}, "yaxis": {"title": {"text": "Returns"}}, "yaxis2": {"overlaying": "y", "side": "right", "title": {"text": "Cum ROI Mult"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('6f8a134d-2344-49bf-876b-6cdd4100bf56');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %%
trace1 = go.Bar(
    x = merged_portfolio_sp_latest_YTD_sp_closing_high['Ticker'][0:10],
    y = merged_portfolio_sp_latest_YTD_sp_closing_high['Pct off High'][0:10])

data = [trace1]
layout = go.Layout(title = 'Adj Close % off High'
    , yaxis=dict(title='% Below Adj Close High')
    , xaxis=dict(title='Ticker')
    , legend=dict(x=.8,y=1)
    )
fig = go.Figure(data=data, layout=layout)
iplot(fig)
# Out:
# <div>
#
#
#             <div id="c2cb8d9d-d70a-45a4-8311-cca638a624a4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("c2cb8d9d-d70a-45a4-8311-cca638a624a4")) {
#                     Plotly.newPlot(
#                         'c2cb8d9d-d70a-45a4-8311-cca638a624a4',
#                         [{"type": "bar", "uid": "7332ef0e-1c08-4d09-925c-3211a568ac9c", "x": ["AAPL", "FB", "JNJ", "MCD", "MTCH", "NFLX", "TWTR", "WMT"], "y": [-0.011344942991661444, -0.055673520120151254, -0.10287548855388062, -0.1286086201909169, 0.0, -0.025275198327286197, -0.34083601286173626, -0.19269071777527236]}],
#                         {"legend": {"x": 0.8, "y": 1}, "title": {"text": "Adj Close % off High"}, "xaxis": {"title": {"text": "Ticker"}}, "yaxis": {"title": {"text": "% Below Adj Close High"}}},
#                         {"showLink": false, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('c2cb8d9d-d70a-45a4-8311-cca638a624a4');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>
